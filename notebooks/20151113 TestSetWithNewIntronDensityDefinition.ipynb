# %%
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline

# %%
info = pd.read_csv('/home/richard/research/tests/Nov11NewIntronDensity/testSetInfoNewUpdated.csv')

# %%
plt.plot(info.gc, info.annotationIntronDensity,'ro')
plt.title('Test Set Distribution')
plt.xlabel('G+C')
plt.ylabel('Intron Density')
plt.xlim(10,70)
plt.ylim(1,6)
# Out:
# (1, 6)

# %%
info
# Out:
#       shortName                                       longName    gc  \
# 0       Aspoch1      Aspergillus ochraceoroseus IBT 24754 v1.0  44.2
# 1        Aurvu1          Auriscalpium vulgare FP105234-Sp v1.0  56.8
# 2        Cenge3                 Cenococcum geophilum 1.58 v2.0  37.5
# 3        Conco1          Conidiobolus coronatus NRRL28638 v1.0  27.7
# 4        Conli1               Coniochaeta ligniaria CBS 111746  51.9
# 5        Croqu1  Cronartium quercuum f. sp. fusiforme G11 v1.0  41.1
# 6        Disac1                     Dissoconium aciculare v1.0  52.7
# 7        Gloin1       Rhizophagus irregularis DAOM 181602 v1.0  27.7
# 8        Hebcy2                Hebeloma cylindrosporum h7 v2.0  48.4
# 9     HypEC38_1                        Hypoxylon sp. EC38 v1.0  40.1
# 10       Obbri1                        Obba rivulosa 3A-2 v1.0  53.6
# 11       Ophdi1         Ophiobolus disseminans CBS 113818 v1.0  51.7
# 12       Phchr2         Phanerochaete chrysosporium RP-78 v2.2  56.8
# 13       Pneji1                         Pneumocystis jirovecii  28.4
# 14  SerlaS7_9_2                    Serpula lacrymans S7.9 v2.0  45.3
# 15       Sphst1                    Sphaerobolus stellatus v1.0  44.4
# 16       Spofi1                       Sporormia fimetaria v1.0  53.8
# 17       Tilan2               Tilletiaria anomala UBC 951 v1.0  56.0
# 18       Trias1         Trichoderma asperellum CBS 433.97 v1.0  47.3
# 19       Veren1             Verruculina enalia CBS 304.66 v1.0  41.2
#
#     annotationIntronDensity  ESIntronDensity  filteredAnnotationIntronDensity
# 0                  2.742920         2.668625                         2.522494
# 1                  4.931555         5.357689                         4.619048
# 2                  2.670176         3.495655                         2.577524
# 3                  3.160395         3.218114                         3.528374
# 4                  2.593246         2.264935                         1.978952
# 5                  4.016015         4.266862                         4.531011
# 6                  1.944040         1.948052                         1.864229
# 7                  3.208206         3.330882                         3.851971
# 8                  5.041882         5.583074                         4.555496
# 9                  2.426896         2.424418                         2.250673
# 10                 5.549950         5.744722                         5.094981
# 11                 2.207689         2.204172                         2.078879
# 12                 4.972733         5.345783                         4.766645
# 13                 5.025927         5.194429                         3.261092
# 14                 5.259169         5.398889                         5.100018
# 15                 4.377487         4.526614                         2.873486
# 16                 2.296779         2.364673                         2.206270
# 17                 2.774329         2.747828                         2.681672
# 18                 2.342797         2.355561                         2.192479
# 19                 2.381540         2.398234                         2.288623
