# %%
'''
cp fasta file to temp, unzip it, calculate gc and delete the file
cp gff3 files to temp, unzip them, calculate intron density and delete all of them

updated Aug 4, use new table with 517 entry to complete gc content, intron density calculation
'''
import pandas as pd
from BCBio.GFF import GFFExaminer
# completeInfo = pd.read_csv("../1_Data/2_completeFileInfo.csv")
folderPath = "/home/richard/1_DataLarge/fasta_gff_gtf_07302015/" #short names
basePath = "/home/richard/tempFile/" #folder where files are manipulated

# %%
## Calculate genome gc
script = ""
for i in range(completeInfo.shape[0]):
    ## copy file
    fastaName = completeInfo.loc[i]['fastaName']
    script += "cp {}/{}/{} {}\n".format(folderPath, 
                                        completeInfo.loc[i]['shortName'], 
                                        fastaName,
                                        basePath)
    ## unzip
    script += "gunzip {}\n".format(fastaName)
    ## calculate gc
    script += 'probuild --gc --seq {} | grep -o "\S\S\.\S" >> genomeGC.csv\n'.format(fastaName[:-3])
    ## remove file
    script += "rm {}\n".format(fastaName[:-3])
    ## another empty line
    script += "\n"
with open("../tempFile/genomeGC.sh","w") as f: f.write(script)
    
# print script

# consolidate genome gc into
genomeGC = pd.read_csv("../tempFile/genomeGC.csv",header = None)
completeInfo['gc'] = genomeGC

# %%
## prepare for intron density calculate 
## copy, unzip files and add intron to files
script = ""
for i in range(completeInfo.shape[0]):
    gff3Name = completeInfo.loc[i]['gff3Name']
    ## copy file
    script += "cp {}/{}/{} {}\n".format(folderPath, 
                                        completeInfo.loc[i]['shortName'], 
                                        gff3Name,
                                        basePath)
    ## unzip
    script += "gunzip {}\n".format(gff3Name)
    ## add intron
    script += '/home/tool/gt/bin/gt gff3 -force -addintrons -o {} {}\n'.format("withIntron_"+gff3Name[:-3], gff3Name[:-3])
    ## another empty line
    script += "\n"
    
with open("../tempFile/gff3Annotation.sh","w") as f: f.write(script)
# print script

# %%
## warning: this block has huge amount of calculation
## caluclate intron density (by biopython extra package: GFFExaminer from BCBio.GFF)
# num_gene = []
# num_intron = []
# num_exon = []

# for i in range(completeInfo.shape[0]):
    
#     gff3Name = completeInfo.loc[i]['gff3Name']
    
#     print "{}, Working on {}.....".format(i,gff3Name)
    
#     examiner = GFFExaminer()
#     in_handle = open(basePath+"withIntron_"+gff3Name[:-3])
#     test = examiner.available_limits(in_handle)
    
#     try:
#         num_gene.append(test['gff_type'][('gene',)])
#     except:
#         print "gene problem: ", gff3Name 
#         num_gene.append(0)
        
#     try:
#         num_exon.append(test['gff_type'][('exon',)])
#     except:
#         print "exon problem: ", gff3Name 
#         num_exon.append(0)
    
#     try:
#         num_intron.append(test['gff_type'][('intron',)])
#     except:
#         print "intron problem: ", gff3Name 
#         num_intron.append(0)

#     in_handle.close()

# %%
## consolidate gene, exon, intron into completeInfo
completeInfo['numGene'] = num_gene
completeInfo['numExon'] = num_exon
completeInfo['numIntron'] = num_intron
completeInfo['intronDensity'] = completeInfo['numIntron']/completeInfo['numGene']
completeInfo.to_csv("../1_Data/3_completeFileInfoWithStatistics.csv", index = False)

# %%
#################################################################################################
## updated Aug 4, use new table with 517 entry to complete gc content, intron density calculation
#################################################################################################
fullTable = pd.read_csv("/home/richard/research/1_DataSmall/2_completeFileInfo/fullTableInfo.csv")

# %%
## Calculate genome gc fullTable
script = ""
for i in range(fullTable.shape[0]):
    ## copy file
    fastaName = fullTable.loc[i]['fastaName']
    if type(fastaName) != float:
        script += "cp {}/{}/{} {}\n".format(folderPath, 
                                            fullTable.loc[i]['shortName'], 
                                            fastaName,
                                            basePath)
        ## unzip
        script += "gunzip {}{}\n".format(basePath,fastaName)
        ## calculate gc
        script += 'probuild --gc --seq {} | grep -o "\S\S\.\S" >> genomeGC.csv\n'.format(fastaName[:-3])
        ## remove file
        script += "rm {}{}\n".format(basePath, fastaName[:-3])
    else:
        script += 'echo NA >> genomeGC.csv\n'
        
    ## another empty line
    script += "\n"
    
# with open("/home/richard/tempFile/genomeGC.sh","w") as f: f.write(script)
# print script

# consolidate genome gc
genomeGC = pd.read_csv("/home/richard/tempFile/genomeGC.csv",header = None)
fullTable['gc'] = genomeGC

# %%
## prepare for intron density calculation with gff3 files
## copy, unzip files and add intron to files
folderPath = "/storage3/w/richard/meta2015/fasta_gff_gtf_07302015/"
basePath = "/storage3/w/richard/tempFile/"


counter = 0
num = 0
script = ""
for i in range(fullTable.shape[0]):
    try:
        gff3Name = fullTable.loc[i]['gff3Name']
        ## copy file
        script += "cp {}/{}/{} {}\n".format(folderPath, 
                                            fullTable.loc[i]['shortName'], 
                                            gff3Name,
                                            basePath)
        ## unzip
        script += "gunzip {}{}\n".format(basePath, gff3Name)
        ## add intron
        script += '/home/tool/gt/bin/gt gff3 -force -addintrons -o {} {}\n'.format("withIntron_"+gff3Name[:-3], gff3Name[:-3])
        ## another empty line
        script += "\n"
        
        num += 1
    except:
        counter += 1
#         print counter, fullTable.loc[i]['shortName'], "does not have gff3 file"
    
# with open(basePath+"gff3Annotation.sh","w") as f: f.write(script)
# print script

# %%
## warning: this block has huge amount of calculation
## caluclate intron density (by biopython extra package: GFFExaminer from BCBio.GFF)
# num_gene = []
# num_intron = []
# num_exon = []

# for i in range(fullTable.shape[0]):
    
#     try:
#         gff3Name = fullTable.loc[i]['gff3Name']
#         print "{}, Working on {}.....".format(i,gff3Name)
    
    
#         examiner = GFFExaminer()
#         in_handle = open(basePath+"withIntron_"+gff3Name[:-3])
#         test = examiner.available_limits(in_handle)
    
#         try:
#             gene = test['gff_type'][('gene',)]
#         except:
#             print "gene problem: ", gff3Name 
#             gene = "NA"
        
#         try:
#             exon = test['gff_type'][('exon',)]
#         except:
#             print "exon problem: ", gff3Name 
#             exon = "NA"
    
#         try:
#             intron = test['gff_type'][('intron',)]
#         except:
#             print "intron problem: ", gff3Name 
#             intron = "NA"
        
#         num_gene.append(gene)
#         num_exon.append(exon)
#         num_intron.append(intron)
        
#     except:
#         num_gene.append("NA")
#         num_exon.append("NA")
#         num_intron.append("NA")

#     in_handle.close()

# %%
## consolidate gene, exon, intron into completeInfo
fullTable['numGene'] = num_gene
fullTable['numExon'] = num_exon
fullTable['numIntron'] = num_intron

intronDensity = []
for i in range(fullTable.shape[0]):
    try:
        density = round(1.*fullTable['numIntron'][i]/fullTable['numGene'][i], 2)
    except:
        density = "NA"
    intronDensity.append(density)
fullTable['intronDensity'] = intronDensity

fullTable.to_csv("../1_DataSmall/fullTableInfoGff3.csv", index = False)

# %%
## prepare for intron density calculation with gff files
import sys
import re
def countGeneExon(filename):
    '''
    args: gff annotation file name
    return: (number of gene, number of exon)
    '''
    geneSet = set()
    exonCount = 0
    with open(filename) as f:
        for line in f:
            if len(line)> 1:
                data = line.split()
            
                gene = data[9]
                pattern = '\".*?\"'
                obj = re.match(pattern, gene)
                gene = obj.group(0)
                geneSet.add(gene)
            
                if data[2] == 'exon':
                    exonCount += 1
    return len(geneSet), exonCount



## copy, unzip files
script = ""
for i in range(fullTable.shape[0]):
    try:
        gffName = fullTable.loc[i]['gffName']
        ## copy file
        script += "cp {}{}/{} {}\n".format(folderPath, 
                                            fullTable.loc[i]['shortName'], 
                                            gffName,
                                            basePath)
        ## unzip
        script += "gunzip {}{}\n".format(basePath, gffName)
        ## another empty line
        script += "\n"
        
    except:
        pass
with open(basePath+"gffAnnotation.sh","w") as f: f.write(script)
# print script

# %%
countGeneExon(basePath+gffName[:-3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-53f8d485f6ee> in <module>()
# ----> 1 countGeneExon(basePath+gffName[:-3])
#
# <ipython-input-47-2bb5e3fbe68e> in countGeneExon(filename)
#      15                 gene = data[9]
#      16                 pattern = '\".*?\"'
# ---> 17                 obj = re.match(pattern, gene)
#      18                 gene = obj.group(0)
#      19                 geneSet.add(gene)
#
# NameError: global name 're' is not defined

# %%
## caluclate intron density from GeneCatalog gff file (by countGeneExon from 4_SelfMadeTool/parse gff file.ipynb)
num_gene = []
num_exon = []

for i in range(fullTable.shape[0]):
    
    try:
        gffName = fullTable.loc[i]['gffName']
        print "{}, Working on {}.....".format(i,gffName[:-3])
        try:
            gene, exon = countGeneExon(basePath+gffName[:-3])
        except:
            print "problem with: ",gffName[:-3]
        num_gene.append(gene)
        num_exon.append(exon)
    except:
        num_gene.append("NA")
        num_exon.append("NA")
# Out:
# 0, Working on Aaoar1_GeneCatalog_genes_20140429.gff.....
# problem with:  Aaoar1_GeneCatalog_genes_20140429.gff
# 1, Working on Acain1_GeneCatalog_genes_20150309.gff.....
# problem with:  Acain1_GeneCatalog_genes_20150309.gff
# 2, Working on Acema1_GeneCatalog_genes_20150224.gff.....
# problem with:  Acema1_GeneCatalog_genes_20150224.gff
# 3, Working on Aciri1_iso_GeneCatalog_genes_20111207.gff.....
# problem with:  Aciri1_iso_GeneCatalog_genes_20111207.gff
# 4, Working on Aciri1_meta_GeneCatalog_genes_20111216.gff.....
# problem with:  Aciri1_meta_GeneCatalog_genes_20111216.gff
# 5, Working on Acral2_GeneCatalog_genes_20110414.gff.....
# problem with:  Acral2_GeneCatalog_genes_20110414.gff
# 6, Working on Acrst1_GeneCatalog_genes_20141022.gff.....
# problem with:  Acrst1_GeneCatalog_genes_20141022.gff
# 9, Working on Agahy1_GeneCatalog_genes_20140307.gff.....
# problem with:  Agahy1_GeneCatalog_genes_20140307.gff
# 10, Working on Altal1_GeneCatalog_genes_20141010.gff.....
# problem with:  Altal1_GeneCatalog_genes_20141010.gff
# 12, Working on Amamu1_GeneCatalog_genes_20120806.gff.....
# problem with:  Amamu1_GeneCatalog_genes_20120806.gff
# 13, Working on Amath1_GeneCatalog_genes_20120702.gff.....
# problem with:  Amath1_GeneCatalog_genes_20120702.gff
# 14, Working on Amnli1_GeneCatalog_genes_20140304.gff.....
# problem with:  Amnli1_GeneCatalog_genes_20140304.gff
# 15, Working on Amore1_GeneCatalog_genes_20110719.gff.....
# problem with:  Amore1_GeneCatalog_genes_20110719.gff
# 16, Working on Antav1_GeneCatalog_genes_20130828.gff.....
# problem with:  Antav1_GeneCatalog_genes_20130828.gff
# 17, Working on Antlo1_GeneCatalog_genes_20130909.gff.....
# problem with:  Antlo1_GeneCatalog_genes_20130909.gff
# 18, Working on Antsi1_GeneCatalog_genes_20130416.gff.....
# problem with:  Antsi1_GeneCatalog_genes_20130416.gff
# 19, Working on Apimo1_GeneCatalog_genes_20120813.gff.....
# problem with:  Apimo1_GeneCatalog_genes_20120813.gff
# 20, Working on Aplpr1_GeneCatalog_genes_20121211.gff.....
# problem with:  Aplpr1_GeneCatalog_genes_20121211.gff
# 21, Working on Armga1_GeneCatalog_genes_20141028.gff.....
# problem with:  Armga1_GeneCatalog_genes_20141028.gff
# 22, Working on Armme1_1_GeneCatalog_genes_20140802.gff.....
# problem with:  Armme1_1_GeneCatalog_genes_20140802.gff
# 23, Working on Artbe1_GeneCatalog_genes_20131209.gff.....
# problem with:  Artbe1_GeneCatalog_genes_20131209.gff
# 24, Working on Artel1_GeneCatalog_genes_20140630.gff.....
# problem with:  Artel1_GeneCatalog_genes_20140630.gff
# 25, Working on Artol1_GeneCatalog_genes_20131209.gff.....
# problem with:  Artol1_GeneCatalog_genes_20131209.gff
# 26, Working on Arxad1_GeneCatalog_genes_20141211.gff.....
# problem with:  Arxad1_GeneCatalog_genes_20141211.gff
# 27, Working on Ascim1_GeneCatalog_genes_20121221.gff.....
# problem with:  Ascim1_GeneCatalog_genes_20121221.gff
# 28, Working on Ascni1_GeneCatalog_genes_20141120.gff.....
# problem with:  Ascni1_GeneCatalog_genes_20141120.gff
# 29, Working on Ascru1_GeneCatalog_genes_20111107.gff.....
# problem with:  Ascru1_GeneCatalog_genes_20111107.gff
# 30, Working on Ascsa1_GeneCatalog_genes_20140116.gff.....
# problem with:  Ascsa1_GeneCatalog_genes_20140116.gff
# 31, Working on Ashgo1_GeneCatalog_genes_20130601.gff.....
# problem with:  Ashgo1_GeneCatalog_genes_20130601.gff
# 32, Working on Ashgo1_1_GeneCatalog_genes_20140830.gff.....
# problem with:  Ashgo1_1_GeneCatalog_genes_20140830.gff
# 34, Working on Aspbr1_GeneCatalog_genes_20120615.gff.....
# problem with:  Aspbr1_GeneCatalog_genes_20120615.gff
# 36, Working on Aspcam1_GeneCatalog_genes_20140128.gff.....
# problem with:  Aspcam1_GeneCatalog_genes_20140128.gff
# 37, Working on Aspcl1_GeneCatalog_genes_20120815.gff.....
# problem with:  Aspcl1_GeneCatalog_genes_20120815.gff
# 38, Working on Aspfl1_GeneCatalog_genes_20121018.gff.....
# problem with:  Aspfl1_GeneCatalog_genes_20121018.gff
# 39, Working on Aspfo1_GeneCatalog_genes_20120615.gff.....
# problem with:  Aspfo1_GeneCatalog_genes_20120615.gff
# 40, Working on Aspfu1_GeneCatalog_genes_20120808.gff.....
# problem with:  Aspfu1_GeneCatalog_genes_20120808.gff
# 41, Working on Aspfu_A1163_1_GeneCatalog_genes_20140107.gff.....
# problem with:  Aspfu_A1163_1_GeneCatalog_genes_20140107.gff
# 42, Working on Aspgl1_GeneCatalog_genes_20121005.gff.....
# problem with:  Aspgl1_GeneCatalog_genes_20121005.gff
# 43, Working on Aspka1_1_GeneCatalog_genes_20140116.gff.....
# problem with:  Aspka1_1_GeneCatalog_genes_20140116.gff
# 44, Working on Aspni7_GeneCatalog_genes_20131226.gff.....
# problem with:  Aspni7_GeneCatalog_genes_20131226.gff
# 45, Working on Aspni_DSM_1_GeneCatalog_genes_20130526.gff.....
# problem with:  Aspni_DSM_1_GeneCatalog_genes_20130526.gff
# 46, Working on Aspni_NRRL3_1_GeneCatalog_genes_20140311.gff.....
# problem with:  Aspni_NRRL3_1_GeneCatalog_genes_20140311.gff
# 47, Working on Aspni_bvT_1_GeneCatalog_genes_20140302.gff.....
# problem with:  Aspni_bvT_1_GeneCatalog_genes_20140302.gff
# 48, Working on Aspnid1_GeneCatalog_genes_20110130.gff.....
# problem with:  Aspnid1_GeneCatalog_genes_20110130.gff
# 49, Working on Aspnov1_GeneCatalog_genes_20140201.gff.....
# problem with:  Aspnov1_GeneCatalog_genes_20140201.gff
# 50, Working on Aspoch1_GeneCatalog_genes_20140127.gff.....
# problem with:  Aspoch1_GeneCatalog_genes_20140127.gff
# 51, Working on Aspor1_GeneCatalog_genes_20120808.gff.....
# problem with:  Aspor1_GeneCatalog_genes_20120808.gff
# 52, Working on Aspph1_GeneCatalog_genes_20140307.gff.....
# problem with:  Aspph1_GeneCatalog_genes_20140307.gff
# 53, Working on Aspste1_GeneCatalog_genes_20140201.gff.....
# problem with:  Aspste1_GeneCatalog_genes_20140201.gff
# 54, Working on Aspsy1_GeneCatalog_genes_20120625.gff.....
# problem with:  Aspsy1_GeneCatalog_genes_20120625.gff
# 55, Working on Aspte1_GeneCatalog_genes_20120919.gff.....
# problem with:  Aspte1_GeneCatalog_genes_20120919.gff
# 56, Working on Asptu1_GeneCatalog_genes_20120711.gff.....
# problem with:  Asptu1_GeneCatalog_genes_20120711.gff
# 57, Working on Aspve1_GeneCatalog_genes_20120621.gff.....
# problem with:  Aspve1_GeneCatalog_genes_20120621.gff
# 58, Working on Aspwe1_GeneCatalog_genes_20120711.gff.....
# problem with:  Aspwe1_GeneCatalog_genes_20120711.gff
# 59, Working on Aspzo1_GeneCatalog_genes_20121010.gff.....
# problem with:  Aspzo1_GeneCatalog_genes_20121010.gff
# 60, Working on Atrsp2_GeneCatalog_genes_20130826.gff.....
# problem with:  Atrsp2_GeneCatalog_genes_20130826.gff
# 61, Working on Aulhe2_GeneCatalog_genes_20130401.gff.....
# problem with:  Aulhe2_GeneCatalog_genes_20130401.gff
# 62, Working on Aurde3_1_GeneCatalog_genes_20130729.gff.....
# problem with:  Aurde3_1_GeneCatalog_genes_20130729.gff
# 63, Working on Aurpu_var_mel1_GeneCatalog_genes_20130418.gff.....
# problem with:  Aurpu_var_mel1_GeneCatalog_genes_20130418.gff
# 64, Working on Aurpu_var_nam1_GeneCatalog_genes_20130418.gff.....
# problem with:  Aurpu_var_nam1_GeneCatalog_genes_20130418.gff
# 65, Working on Aurpu_var_pul1_GeneCatalog_genes_20130219.gff.....
# problem with:  Aurpu_var_pul1_GeneCatalog_genes_20130219.gff
# 66, Working on Aurpu_var_sub1_GeneCatalog_genes_20120515.gff.....
# problem with:  Aurpu_var_sub1_GeneCatalog_genes_20120515.gff
# 67, Working on Aurvu1_GeneCatalog_genes_20140723.gff.....
# problem with:  Aurvu1_GeneCatalog_genes_20140723.gff
# 68, Working on Babin1_GeneCatalog_genes_20120306.gff.....
# problem with:  Babin1_GeneCatalog_genes_20120306.gff
# 69, Working on Bacci1_GeneCatalog_genes_20130730.gff.....
# problem with:  Bacci1_GeneCatalog_genes_20130730.gff
# 70, Working on Basun1_GeneCatalog_genes_20150127.gff.....
# problem with:  Basun1_GeneCatalog_genes_20150127.gff
# 72, Working on Bauco1_GeneCatalog_genes_20110511.gff.....
# problem with:  Bauco1_GeneCatalog_genes_20110511.gff
# 73, Working on Beaba1_GeneCatalog_genes_20130926.gff.....
# problem with:  Beaba1_GeneCatalog_genes_20130926.gff
# 74, Working on Bimnz1_GeneCatalog_genes_20150128.gff.....
# problem with:  Bimnz1_GeneCatalog_genes_20150128.gff
# 75, Working on Bjead1_1_GeneCatalog_genes_20110614.gff.....
# problem with:  Bjead1_1_GeneCatalog_genes_20110614.gff
# 76, Working on Blugr1_GeneCatalog_genes_20131023.gff.....
# problem with:  Blugr1_GeneCatalog_genes_20131023.gff
# 77, Working on Boled1_GeneCatalog_genes_20130211.gff.....
# problem with:  Boled1_GeneCatalog_genes_20130211.gff
# 78, Working on Botbo1_GeneCatalog_genes_20110803.gff.....
# problem with:  Botbo1_GeneCatalog_genes_20110803.gff
# 79, Working on Botci1_GeneCatalog_genes_20110903.gff.....
# problem with:  Botci1_GeneCatalog_genes_20110903.gff
# 80, Working on Botdo1_1_GeneCatalog_genes_20150128.gff.....
# problem with:  Botdo1_1_GeneCatalog_genes_20150128.gff
# 81, Working on Bysci1_GeneCatalog_genes_20140627.gff.....
# problem with:  Bysci1_GeneCatalog_genes_20140627.gff
# 82, Working on Cadsp1_GeneCatalog_genes_20140317.gff.....
# problem with:  Cadsp1_GeneCatalog_genes_20140317.gff
# 83, Working on Calco1_GeneCatalog_genes_20130417.gff.....
# problem with:  Calco1_GeneCatalog_genes_20130417.gff
# 84, Working on Calvi1_GeneCatalog_genes_20130829.gff.....
# problem with:  Calvi1_GeneCatalog_genes_20130829.gff
# 85, Working on Canar1_GeneCatalog_genes_20111127.gff.....
# problem with:  Canar1_GeneCatalog_genes_20111127.gff
# 86, Working on Canca1_GeneCatalog_genes_20110525.gff.....
# problem with:  Canca1_GeneCatalog_genes_20110525.gff
# 87, Working on Canta1_GeneCatalog_genes_20120131.gff.....
# problem with:  Canta1_GeneCatalog_genes_20120131.gff
# 89, Working on Catan1_GeneCatalog_genes_20120622.gff.....
# problem with:  Catan1_GeneCatalog_genes_20120622.gff
# 90, Working on Cenge3_GeneCatalog_genes_20130403.gff.....
# problem with:  Cenge3_GeneCatalog_genes_20130403.gff
# 91, Working on Cepal1_1_GeneCatalog_genes_20150113.gff.....
# problem with:  Cepal1_1_GeneCatalog_genes_20150113.gff
# 92, Working on Cepfr1_1_GeneCatalog_genes_20150115.gff.....
# problem with:  Cepfr1_1_GeneCatalog_genes_20150115.gff
# 93, Working on CerAGI_GeneCatalog_genes_20150524.gff.....
# problem with:  CerAGI_GeneCatalog_genes_20150524.gff
# 94, Working on Cersp1_GeneCatalog_genes_20150406.gff.....
# problem with:  Cersp1_GeneCatalog_genes_20150406.gff
# 96, Working on Cerun2_GeneCatalog_genes_20130111.gff.....
# problem with:  Cerun2_GeneCatalog_genes_20130111.gff
# 97, Working on Cerzm1_GeneCatalog_genes_20111029.gff.....
# problem with:  Cerzm1_GeneCatalog_genes_20111029.gff
# 99, Working on Chalo1_GeneCatalog_genes_20130611.gff.....
# problem with:  Chalo1_GeneCatalog_genes_20130611.gff
# 100, Working on Chiap1_GeneCatalog_genes_20150110.gff.....
# problem with:  Chiap1_GeneCatalog_genes_20150110.gff
# 101, Working on Chove1_GeneCatalog_genes_20131210.gff.....
# problem with:  Chove1_GeneCatalog_genes_20131210.gff
# 102, Working on ClaPMI390_GeneCatalog_genes_20140716.gff.....
# problem with:  ClaPMI390_GeneCatalog_genes_20140716.gff
# 103, Working on Clael1_GeneCatalog_genes_20140828.gff.....
# problem with:  Clael1_GeneCatalog_genes_20140828.gff
# 104, Working on Clafu1_GeneCatalog_genes_20110826.gff.....
# problem with:  Clafu1_GeneCatalog_genes_20110826.gff
# 105, Working on Clagr3_GeneCatalog_genes_20111121.gff.....
# problem with:  Clagr3_GeneCatalog_genes_20111121.gff
# 106, Working on Clapy1_GeneCatalog_genes_20140612.gff.....
# problem with:  Clapy1_GeneCatalog_genes_20140612.gff
# 107, Working on Cloro1_GeneCatalog_genes_20150131.gff.....
# problem with:  Cloro1_GeneCatalog_genes_20150131.gff
# 108, Working on Cocca1_GeneCatalog_genes_20120427.gff.....
# problem with:  Cocca1_GeneCatalog_genes_20120427.gff
# 109, Working on CocheC4_1_GeneCatalog_genes_20110824.gff.....
# problem with:  CocheC4_1_GeneCatalog_genes_20110824.gff
# 110, Working on CocheC5_3_GeneCatalog_genes_20110901.gff.....
# problem with:  CocheC5_3_GeneCatalog_genes_20110901.gff
# 111, Working on Cocim1_GeneCatalog_genes_20130907.gff.....
# problem with:  Cocim1_GeneCatalog_genes_20130907.gff
# 112, Working on Coclu2_GeneCatalog_genes_20120521.gff.....
# problem with:  Coclu2_GeneCatalog_genes_20120521.gff
# 113, Working on Cocmi1_GeneCatalog_genes_20120427.gff.....
# problem with:  Cocmi1_GeneCatalog_genes_20120427.gff
# 114, Working on Cocsa1_GeneCatalog_genes_20110610.gff.....
# problem with:  Cocsa1_GeneCatalog_genes_20110610.gff
# 115, Working on Cocvi1_GeneCatalog_genes_20120501.gff.....
# problem with:  Cocvi1_GeneCatalog_genes_20120501.gff
# 116, Working on Coere1_GeneCatalog_genes_20110909.gff.....
# problem with:  Coere1_GeneCatalog_genes_20110909.gff
# 117, Working on Colca1_GeneCatalog_genes_20150403.gff.....
# problem with:  Colca1_GeneCatalog_genes_20150403.gff
# 118, Working on Coler1_GeneCatalog_genes_20141231.gff.....
# problem with:  Coler1_GeneCatalog_genes_20141231.gff
# 119, Working on Colfa1_GeneCatalog_genes_20141228.gff.....
# problem with:  Colfa1_GeneCatalog_genes_20141228.gff
# 120, Working on Colgr1_GeneCatalog_genes_20130906.gff.....
# problem with:  Colgr1_GeneCatalog_genes_20130906.gff
# 121, Working on Colhi1_GeneCatalog_genes_20131030.gff.....
# problem with:  Colhi1_GeneCatalog_genes_20131030.gff
# 122, Working on Colso1_GeneCatalog_genes_20141229.gff.....
# problem with:  Colso1_GeneCatalog_genes_20141229.gff
# 123, Working on Colsu1_GeneCatalog_genes_20150101.gff.....
# problem with:  Colsu1_GeneCatalog_genes_20150101.gff
# 124, Working on Colzo1_GeneCatalog_genes_20150103.gff.....
# problem with:  Colzo1_GeneCatalog_genes_20150103.gff
# 125, Working on ConPMI546_GeneCatalog_genes_20140720.gff.....
# problem with:  ConPMI546_GeneCatalog_genes_20140720.gff
# 126, Working on Conco1_GeneCatalog_genes_20120213.gff.....
# problem with:  Conco1_GeneCatalog_genes_20120213.gff
# 127, Working on Conli1_GeneCatalog_genes_20130808.gff.....
# problem with:  Conli1_GeneCatalog_genes_20130808.gff
# 128, Working on Conlig1_GeneCatalog_genes_20140604.gff.....
# problem with:  Conlig1_GeneCatalog_genes_20140604.gff
# 129, Working on Conpu1_GeneCatalog_genes_20101116.gff.....
# problem with:  Conpu1_GeneCatalog_genes_20101116.gff
# 130, Working on Conth1_GeneCatalog_genes_20141003.gff.....
# problem with:  Conth1_GeneCatalog_genes_20141003.gff
# 132, Working on Copci_AmutBmut1_GeneCatalog_genes_20130522.gff.....
# problem with:  Copci_AmutBmut1_GeneCatalog_genes_20130522.gff
# 133, Working on Corca1_GeneCatalog_genes_20140615.gff.....
# problem with:  Corca1_GeneCatalog_genes_20140615.gff
# 134, Working on Corgl3_GeneCatalog_genes_20130626.gff.....
# problem with:  Corgl3_GeneCatalog_genes_20130626.gff
# 135, Working on Corma2_GeneCatalog_genes_20150506.gff.....
# problem with:  Corma2_GeneCatalog_genes_20150506.gff
# 136, Working on Cormi1_GeneCatalog_genes_20131203.gff.....
# problem with:  Cormi1_GeneCatalog_genes_20131203.gff
# 137, Working on Croqu1_GeneCatalog_genes_20120612.gff.....
# problem with:  Croqu1_GeneCatalog_genes_20120612.gff
# 139, Working on Cryne_JEC21_1_GeneCatalog_genes_20120305.gff.....
# problem with:  Cryne_JEC21_1_GeneCatalog_genes_20120305.gff
# 140, Working on Crypa2.filtered_proteins.FrozenGeneCatalog_20091214.gff3.....
# problem with:  Crypa2.filtered_proteins.FrozenGeneCatalog_20091214.gff3
# 141, Working on Cryvi1_GeneCatalog_genes_20130104.gff.....
# problem with:  Cryvi1_GeneCatalog_genes_20130104.gff
# 142, Working on Cucbe1_GeneCatalog_genes_20130102.gff.....
# problem with:  Cucbe1_GeneCatalog_genes_20130102.gff
# 143, Working on Cybja1_GeneCatalog_genes_20121210.gff.....
# problem with:  Cybja1_GeneCatalog_genes_20121210.gff
# 144, Working on Cylto1_GeneCatalog_genes_20130411.gff.....
# problem with:  Cylto1_GeneCatalog_genes_20130411.gff
# 145, Working on Dacsp1_GeneCatalog_genes_20110131.gff.....
# problem with:  Dacsp1_GeneCatalog_genes_20110131.gff
# 146, Working on Daequ1_GeneCatalog_genes_20130110.gff.....
# problem with:  Daequ1_GeneCatalog_genes_20130110.gff
# 147, Working on DalEC12_1_GeneCatalog_genes_20111212.gff.....
# problem with:  DalEC12_1_GeneCatalog_genes_20111212.gff
# 148, Working on Debha1_GeneCatalog_genes_20130209.gff.....
# problem with:  Debha1_GeneCatalog_genes_20130209.gff
# 149, Working on Decga1_GeneCatalog_genes_20150425.gff.....
# problem with:  Decga1_GeneCatalog_genes_20150425.gff
# 150, Working on Dekbr2_GeneCatalog_genes_20120306.gff.....
# problem with:  Dekbr2_GeneCatalog_genes_20120306.gff
# 151, Working on Delco1_GeneCatalog_genes_20140624.gff.....
# problem with:  Delco1_GeneCatalog_genes_20140624.gff
# 152, Working on Denbi1_GeneCatalog_genes_20131210.gff.....
# problem with:  Denbi1_GeneCatalog_genes_20131210.gff
# 153, Working on Dicsq1_GeneCatalog_genes_20101110.gff.....
# problem with:  Dicsq1_GeneCatalog_genes_20101110.gff
# 154, Working on Didex1_GeneCatalog_genes_20120924.gff.....
# problem with:  Didex1_GeneCatalog_genes_20120924.gff
# 155, Working on Diocr1_GeneCatalog_genes_20130123.gff.....
# problem with:  Diocr1_GeneCatalog_genes_20130123.gff
# 156, Working on Disac1_GeneCatalog_genes_20130805.gff.....
# problem with:  Disac1_GeneCatalog_genes_20130805.gff
# 157, Working on Dotse1_GeneCatalog_genes_20100818.gff.....
# problem with:  Dotse1_GeneCatalog_genes_20100818.gff
# 158, Working on Dotsy1_GeneCatalog_genes_20131210.gff.....
# problem with:  Dotsy1_GeneCatalog_genes_20131210.gff
# 159, Working on Elmca1_GeneCatalog_genes_20140827.gff.....
# problem with:  Elmca1_GeneCatalog_genes_20140827.gff
# 160, Working on Enccu1_GeneCatalog_genes_20130927.gff.....
# problem with:  Enccu1_GeneCatalog_genes_20130927.gff
# 161, Working on Enche1_GeneCatalog_genes_20131209.gff.....
# problem with:  Enche1_GeneCatalog_genes_20131209.gff
# 162, Working on Encin1_GeneCatalog_genes_20131101.gff.....
# problem with:  Encin1_GeneCatalog_genes_20131101.gff
# 163, Working on Encro1_GeneCatalog_genes_20131209.gff.....
# problem with:  Encro1_GeneCatalog_genes_20131209.gff
# 164, Working on Entbi1_GeneCatalog_genes_20140106.gff.....
# problem with:  Entbi1_GeneCatalog_genes_20140106.gff
# 165, Working on Erebi1_GeneCatalog_genes_20150104.gff.....
# problem with:  Erebi1_GeneCatalog_genes_20150104.gff
# 166, Working on Eryha1_GeneCatalog_genes_20141112.gff.....
# problem with:  Eryha1_GeneCatalog_genes_20141112.gff
# 167, Working on Eurhe1_GeneCatalog_genes_20120312.gff.....
# problem with:  Eurhe1_GeneCatalog_genes_20120312.gff
# 168, Working on Eutla1_GeneCatalog_genes_20130916.gff.....
# problem with:  Eutla1_GeneCatalog_genes_20130916.gff
# 169, Working on Exigl1_GeneCatalog_genes_20130529.gff.....
# problem with:  Exigl1_GeneCatalog_genes_20130529.gff
# 170, Working on Exova1_GeneCatalog_genes_20131210.gff.....
# problem with:  Exova1_GeneCatalog_genes_20131210.gff
# 171, Working on Fibra1_GeneCatalog_genes_20131030.gff.....
# problem with:  Fibra1_GeneCatalog_genes_20131030.gff
# 172, Working on Fibsp1_GeneCatalog_genes_20131122.gff.....
# problem with:  Fibsp1_GeneCatalog_genes_20131122.gff
# 173, Working on Fishe1_GeneCatalog_genes_20130122.gff.....
# problem with:  Fishe1_GeneCatalog_genes_20130122.gff
# 174, Working on Fomme1_GeneCatalog_genes_20101122.gff.....
# problem with:  Fomme1_GeneCatalog_genes_20101122.gff
# 175, Working on Fompi3_GeneCatalog_genes_20120705.gff.....
# problem with:  Fompi3_GeneCatalog_genes_20120705.gff
# 176, Working on Fusfu1_GeneCatalog_genes_20130915.gff.....
# problem with:  Fusfu1_GeneCatalog_genes_20130915.gff
# 177, Working on Fusgr1_GeneCatalog_genes_20110524.gff.....
# problem with:  Fusgr1_GeneCatalog_genes_20110524.gff
# 178, Working on Fusox1_GeneCatalog_genes_20110522.gff.....
# problem with:  Fusox1_GeneCatalog_genes_20110522.gff
# 179, Working on Fusox2_GeneCatalog_genes_20150720.gff.....
# problem with:  Fusox2_GeneCatalog_genes_20150720.gff
# 180, Working on Fusve1_GeneCatalog_genes_20130924.gff.....
# problem with:  Fusve1_GeneCatalog_genes_20130924.gff
# 181, Working on Fusve2_GeneCatalog_genes_20150720.gff.....
# problem with:  Fusve2_GeneCatalog_genes_20150720.gff
# 182, Working on Galma1_GeneCatalog_genes_20110628.gff.....
# problem with:  Galma1_GeneCatalog_genes_20110628.gff
# 183, Working on Ganpr1_GeneCatalog_genes_20111215.gff.....
# problem with:  Ganpr1_GeneCatalog_genes_20111215.gff
# 184, Working on Gansp1_GeneCatalog_genes_20110326.gff.....
# problem with:  Gansp1_GeneCatalog_genes_20110326.gff
# 185, Working on Glalo1_GeneCatalog_genes_20131021.gff.....
# problem with:  Glalo1_GeneCatalog_genes_20131021.gff
# 186, Working on Gloac1_GeneCatalog_genes_20121120.gff.....
# problem with:  Gloac1_GeneCatalog_genes_20121120.gff
# 187, Working on Gloci1_GeneCatalog_genes_20121001.gff.....
# problem with:  Gloci1_GeneCatalog_genes_20121001.gff
# 188, Working on Gloin1_GeneCatalog_genes_20120510.gff.....
# problem with:  Gloin1_GeneCatalog_genes_20120510.gff
# 189, Working on Glost2_GeneCatalog_genes_20140303.gff.....
# problem with:  Glost2_GeneCatalog_genes_20140303.gff
# 190, Working on Glotr1_1_GeneCatalog_genes_20100928.gff.....
# problem with:  Glotr1_1_GeneCatalog_genes_20100928.gff
# 191, Working on Grocl1_GeneCatalog_genes_20131017.gff.....
# problem with:  Grocl1_GeneCatalog_genes_20131017.gff
# 192, Working on Guyne1_GeneCatalog_genes_20140406.gff.....
# problem with:  Guyne1_GeneCatalog_genes_20140406.gff
# 193, Working on Gyman1_GeneCatalog_genes_20140729.gff.....
# problem with:  Gyman1_GeneCatalog_genes_20140729.gff
# 194, Working on Gymau1_GeneCatalog_genes_20130805.gff.....
# problem with:  Gymau1_GeneCatalog_genes_20130805.gff
# 195, Working on Gymch1_GeneCatalog_genes_20140623.gff.....
# problem with:  Gymch1_GeneCatalog_genes_20140623.gff
# 196, Working on Gymci1_1_GeneCatalog_genes_20130902.gff.....
# problem with:  Gymci1_1_GeneCatalog_genes_20130902.gff
# 197, Working on Gymlu1_GeneCatalog_genes_20110803.gff.....
# problem with:  Gymlu1_GeneCatalog_genes_20110803.gff
# 198, Working on Gyrli1_GeneCatalog_genes_20140325.gff.....
# problem with:  Gyrli1_GeneCatalog_genes_20140325.gff
# 199, Working on Hanpo2_GeneCatalog_genes_20100927.gff.....
# problem with:  Hanpo2_GeneCatalog_genes_20100927.gff
# 200, Working on Hanva1_1_GeneCatalog_genes_20120316.gff.....
# problem with:  Hanva1_1_GeneCatalog_genes_20120316.gff
# 201, Working on Hebcy2_GeneCatalog_genes_20120913.gff.....
# problem with:  Hebcy2_GeneCatalog_genes_20120913.gff
# 202, Working on Hesve2finisherSC_GeneCatalog_genes_20150707.gff.....
# problem with:  Hesve2finisherSC_GeneCatalog_genes_20150707.gff
# 203, Working on Hetan2.filtered_proteins.FrozenGeneCatalog_20120113.gff3.....
# problem with:  Hetan2.filtered_proteins.FrozenGeneCatalog_20120113.gff3
# 204, Working on Hetpy1_GeneCatalog_genes_20140310.gff.....
# problem with:  Hetpy1_GeneCatalog_genes_20140310.gff
# 205, Working on Hisca1_GeneCatalog_genes_20130826.gff.....
# problem with:  Hisca1_GeneCatalog_genes_20130826.gff
# 206, Working on Hyabl1_GeneCatalog_genes_20150410.gff.....
# problem with:  Hyabl1_GeneCatalog_genes_20150410.gff
# 207, Working on Hydpi2_GeneCatalog_genes_20120511.gff.....
# problem with:  Hydpi2_GeneCatalog_genes_20120511.gff
# 208, Working on Hydru2_GeneCatalog_genes_20150110.gff.....
# problem with:  Hydru2_GeneCatalog_genes_20150110.gff
# 209, Working on HypCI4A_1_GeneCatalog_genes_20111212.gff.....
# problem with:  HypCI4A_1_GeneCatalog_genes_20111212.gff
# 210, Working on HypCO275_1_GeneCatalog_genes_20120126.gff.....
# problem with:  HypCO275_1_GeneCatalog_genes_20120126.gff
# 211, Working on HypEC38_1_GeneCatalog_genes_20120308.gff.....
# problem with:  HypEC38_1_GeneCatalog_genes_20120308.gff
# 212, Working on Hypbu1_GeneCatalog_genes_20120125.gff.....
# problem with:  Hypbu1_GeneCatalog_genes_20120125.gff
# 213, Working on Hypsu1_GeneCatalog_genes_20110822.gff.....
# problem with:  Hypsu1_GeneCatalog_genes_20110822.gff
# 214, Working on Hyspu1_1_GeneCatalog_genes_20150205.gff.....
# problem with:  Hyspu1_1_GeneCatalog_genes_20150205.gff
# 215, Working on Ilysp1_GeneCatalog_genes_20121116.gff.....
# problem with:  Ilysp1_GeneCatalog_genes_20121116.gff
# 216, Working on Jaaar1_GeneCatalog_genes_20110803.gff.....
# problem with:  Jaaar1_GeneCatalog_genes_20110803.gff
# 217, Working on Jamsp1_GeneCatalog_genes_20141226.gff.....
# problem with:  Jamsp1_GeneCatalog_genes_20141226.gff
# 218, Working on Karrh1_GeneCatalog_genes_20140225.gff.....
# problem with:  Karrh1_GeneCatalog_genes_20140225.gff
# 219, Working on Kazaf1_GeneCatalog_genes_20150111.gff.....
# problem with:  Kazaf1_GeneCatalog_genes_20150111.gff
# 220, Working on Klula1_GeneCatalog_genes_20130227.gff.....
# problem with:  Klula1_GeneCatalog_genes_20130227.gff
# 221, Working on Lacam1_GeneCatalog_genes_20121009.gff.....
# problem with:  Lacam1_GeneCatalog_genes_20121009.gff
# 222, Working on Lacbi2_GeneCatalog_genes_20110203.gff.....
# problem with:  Lacbi2_GeneCatalog_genes_20110203.gff
# 223, Working on Laesu1_GeneCatalog_genes_20130128.gff.....
# problem with:  Laesu1_GeneCatalog_genes_20130128.gff
# 224, Working on Leisp1_GeneCatalog_genes_20141127.gff.....
# problem with:  Leisp1_GeneCatalog_genes_20141127.gff
# 225, Working on Lenfl1_GeneCatalog_genes_20121217.gff.....
# problem with:  Lenfl1_GeneCatalog_genes_20121217.gff
# 226, Working on Lenti6_1_GeneCatalog_genes_20130903.gff.....
# problem with:  Lenti6_1_GeneCatalog_genes_20130903.gff
# 227, Working on Lenti7_1_GeneCatalog_genes_20130905.gff.....
# problem with:  Lenti7_1_GeneCatalog_genes_20130905.gff
# 228, Working on Lepmu1_GeneCatalog_genes_20110301.gff.....
# problem with:  Lepmu1_GeneCatalog_genes_20110301.gff
# 229, Working on Leppa1_GeneCatalog_genes_20130322.gff.....
# problem with:  Leppa1_GeneCatalog_genes_20130322.gff
# 230, Working on Leugo1_1_GeneCatalog_genes_20141030.gff.....
# problem with:  Leugo1_1_GeneCatalog_genes_20141030.gff
# 231, Working on Leumo1_GeneCatalog_genes_20131220.gff.....
# problem with:  Leumo1_GeneCatalog_genes_20131220.gff
# 232, Working on Lichy1_GeneCatalog_genes_20130506.gff.....
# problem with:  Lichy1_GeneCatalog_genes_20130506.gff
# 233, Working on Linin1_GeneCatalog_genes_20141206.gff.....
# problem with:  Linin1_GeneCatalog_genes_20141206.gff
# 234, Working on Linth1_GeneCatalog_genes_20150309.gff.....
# problem with:  Linth1_GeneCatalog_genes_20150309.gff
# 235, Working on Lipst1_1_GeneCatalog_genes_20110609.gff.....
# problem with:  Lipst1_1_GeneCatalog_genes_20110609.gff
# 236, Working on Lizem1_GeneCatalog_genes_20150430.gff.....
# problem with:  Lizem1_GeneCatalog_genes_20150430.gff
# 237, Working on Lolmi1_GeneCatalog_genes_20150504.gff.....
# problem with:  Lolmi1_GeneCatalog_genes_20150504.gff
# 238, Working on Lopma1_GeneCatalog_genes_20130805.gff.....
# problem with:  Lopma1_GeneCatalog_genes_20130805.gff
# 239, Working on Lopmy1_GeneCatalog_genes_20140604.gff.....
# problem with:  Lopmy1_GeneCatalog_genes_20140604.gff
# 240, Working on Lopni1_GeneCatalog_genes_20150213.gff.....
# problem with:  Lopni1_GeneCatalog_genes_20150213.gff
# 241, Working on Lorju1_GeneCatalog_genes_20150110.gff.....
# problem with:  Lorju1_GeneCatalog_genes_20150110.gff
# 242, Working on Macan1_GeneCatalog_genes_20140424.gff.....
# problem with:  Macan1_GeneCatalog_genes_20140424.gff
# 243, Working on Macfu1_GeneCatalog_genes_20130625.gff.....
# problem with:  Macfu1_GeneCatalog_genes_20130625.gff
# 244, Working on Macph1_GeneCatalog_genes_20131211.gff.....
# problem with:  Macph1_GeneCatalog_genes_20131211.gff
# 245, Working on Maggr1_GeneCatalog_genes_20110524.gff.....
# problem with:  Maggr1_GeneCatalog_genes_20110524.gff
# 246, Working on Magpo1_GeneCatalog_genes_20150720.gff.....
# problem with:  Magpo1_GeneCatalog_genes_20150720.gff
# 248, Working on Malsy1_1_GeneCatalog_genes_20140109.gff.....
# problem with:  Malsy1_1_GeneCatalog_genes_20140109.gff
# 249, Working on Marbr1_GeneCatalog_genes_20141203.gff.....
# problem with:  Marbr1_GeneCatalog_genes_20141203.gff
# 250, Working on Marfi1_GeneCatalog_genes_20141220.gff.....
# problem with:  Marfi1_GeneCatalog_genes_20141220.gff
# 251, Working on Marpt1_GeneCatalog_genes_20140919.gff.....
# problem with:  Marpt1_GeneCatalog_genes_20140919.gff
# 252, Working on Maseb1_GeneCatalog_genes_20141122.gff.....
# problem with:  Maseb1_GeneCatalog_genes_20141122.gff
# 253, Working on Meimi1_GeneCatalog_genes_20150112.gff.....
# problem with:  Meimi1_GeneCatalog_genes_20150112.gff
# 254, Working on Melbi2_GeneCatalog_genes_20130225.gff.....
# problem with:  Melbi2_GeneCatalog_genes_20130225.gff
# 255, Working on Melli1_GeneCatalog_genes_20150227.gff.....
# problem with:  Melli1_GeneCatalog_genes_20150227.gff
# 256, Working on Mlaricis_populina.FrozenGeneCatalog_20091005.gff.....
# problem with:  Mlaricis_populina.FrozenGeneCatalog_20091005.gff
# 257, Working on Melpu1_GeneCatalog_genes_20130415.gff.....
# problem with:  Melpu1_GeneCatalog_genes_20130415.gff
# 258, Working on Melsp1_GeneCatalog_genes_20121023.gff.....
# problem with:  Melsp1_GeneCatalog_genes_20121023.gff
# 259, Working on Melti1_GeneCatalog_genes_20150427.gff.....
# problem with:  Melti1_GeneCatalog_genes_20150427.gff
# 260, Working on Melva1_GeneCatalog_genes_20130406.gff.....
# problem with:  Melva1_GeneCatalog_genes_20130406.gff
# 261, Working on Metac1_GeneCatalog_genes_20131003.gff.....
# problem with:  Metac1_GeneCatalog_genes_20131003.gff
# 262, Working on Metan1_GeneCatalog_genes_20131005.gff.....
# problem with:  Metan1_GeneCatalog_genes_20131005.gff
# 263, Working on Metbi1_GeneCatalog_genes_20120327.gff.....
# problem with:  Metbi1_GeneCatalog_genes_20120327.gff
# 264, Working on Micca1_GeneCatalog_genes_20130828.gff.....
# problem with:  Micca1_GeneCatalog_genes_20130828.gff
# 265, Working on Mictr1_GeneCatalog_genes_20140926.gff.....
# problem with:  Mictr1_GeneCatalog_genes_20140926.gff
# 266, Working on Mixos1_GeneCatalog_genes_20120207.gff.....
# problem with:  Mixos1_GeneCatalog_genes_20120207.gff
# 267, Working on Monha1_GeneCatalog_genes_20131210.gff.....
# problem with:  Monha1_GeneCatalog_genes_20131210.gff
# 268, Working on Monpe1_1_GeneCatalog_genes_20131213.gff.....
# problem with:  Monpe1_1_GeneCatalog_genes_20131213.gff
# 269, Working on Monpu1_GeneCatalog_genes_20130806.gff.....
# problem with:  Monpu1_GeneCatalog_genes_20130806.gff
# 270, Working on Monru1_GeneCatalog_genes_20121211.gff.....
# problem with:  Monru1_GeneCatalog_genes_20121211.gff
# 271, Working on Morco1_GeneCatalog_genes_20140113.gff.....
# problem with:  Morco1_GeneCatalog_genes_20140113.gff
# 272, Working on Morel1_GeneCatalog_genes_20120920.gff.....
# problem with:  Morel1_GeneCatalog_genes_20120920.gff
# 274, Working on Mutel1_GeneCatalog_genes_20150215.gff.....
# problem with:  Mutel1_GeneCatalog_genes_20150215.gff
# 275, Working on Mycfi2.filtered_proteins.FrozenGeneCatalog_20100402.gff3.....
# problem with:  Mycfi2.filtered_proteins.FrozenGeneCatalog_20100402.gff3
# 276, Working on Mgraminicolav2.FrozenGeneCatalog20080910.gff.....
# problem with:  Mgraminicolav2.FrozenGeneCatalog20080910.gff
# 277, Working on Myche1_GeneCatalog_genes_20150518.gff.....
# problem with:  Myche1_GeneCatalog_genes_20150518.gff
# 278, Working on Myrdu1_GeneCatalog_genes_20121211.gff.....
# problem with:  Myrdu1_GeneCatalog_genes_20121211.gff
# 279, Working on Myrin1_GeneCatalog_genes_20140928.gff.....
# problem with:  Myrin1_GeneCatalog_genes_20140928.gff
# 280, Working on Mytre1_GeneCatalog_genes_20150115.gff.....
# problem with:  Mytre1_GeneCatalog_genes_20150115.gff
# 281, Working on Nadfu1_GeneCatalog_genes_20110909.gff.....
# problem with:  Nadfu1_GeneCatalog_genes_20110909.gff
# 282, Working on Naifl1_GeneCatalog_genes_20140403.gff.....
# problem with:  Naifl1_GeneCatalog_genes_20140403.gff
# 284, Working on Nempa1_GeneCatalog_genes_20130904.gff.....
# problem with:  Nempa1_GeneCatalog_genes_20130904.gff
# 285, Working on Neofi1_GeneCatalog_genes_20120815.gff.....
# problem with:  Neofi1_GeneCatalog_genes_20120815.gff
# 286, Working on Neole1_GeneCatalog_genes_20130125.gff.....
# problem with:  Neole1_GeneCatalog_genes_20130125.gff
# 287, Working on Neopa1_GeneCatalog_genes_20130909.gff.....
# problem with:  Neopa1_GeneCatalog_genes_20130909.gff
# 288, Working on Neucr2_GeneCatalog_genes_20130412.gff.....
# problem with:  Neucr2_GeneCatalog_genes_20130412.gff
# 289, Working on Neucr_trp3_1_GeneCatalog_genes_20140324.gff.....
# problem with:  Neucr_trp3_1_GeneCatalog_genes_20140324.gff
# 291, Working on Neute_matA2.filtered_proteins.FilteredModels1.gff3.....
# problem with:  Neute_matA2.filtered_proteins.FilteredModels1.gff3
# 293, Working on Nieex1_GeneCatalog_genes_20140925.gff.....
# problem with:  Nieex1_GeneCatalog_genes_20140925.gff
# 294, Working on Nosce1_GeneCatalog_genes_20140109.gff.....
# problem with:  Nosce1_GeneCatalog_genes_20140109.gff
# 295, Working on Obbri1_GeneCatalog_genes_20140615.gff.....
# problem with:  Obbri1_GeneCatalog_genes_20140615.gff
# 296, Working on Oidma1_GeneCatalog_genes_20110606.gff.....
# problem with:  Oidma1_GeneCatalog_genes_20110606.gff
# 297, Working on Ompol1_GeneCatalog_genes_20130516.gff.....
# problem with:  Ompol1_GeneCatalog_genes_20130516.gff
# 298, Working on Onnsc1_GeneCatalog_genes_20150419.gff.....
# problem with:  Onnsc1_GeneCatalog_genes_20150419.gff
# 299, Working on Ophdi1_GeneCatalog_genes_20140614.gff.....
# problem with:  Ophdi1_GeneCatalog_genes_20140614.gff
# 300, Working on Ophpc1_GeneCatalog_genes_20130927.gff.....
# problem with:  Ophpc1_GeneCatalog_genes_20130927.gff
# 301, Working on Orpsp1_1_GeneCatalog_genes_20140826.gff.....
# problem with:  Orpsp1_1_GeneCatalog_genes_20140826.gff
# 302, Working on Pacta1_2_GeneCatalog_genes_20110630.gff.....
# problem with:  Pacta1_2_GeneCatalog_genes_20110630.gff
# 303, Working on Panru1_GeneCatalog_genes_20141214.gff.....
# problem with:  Panru1_GeneCatalog_genes_20141214.gff
# 304, Working on Panst_KUC8834_1_1_GeneCatalog_genes_20140710.gff.....
# problem with:  Panst_KUC8834_1_1_GeneCatalog_genes_20140710.gff
# 305, Working on Parbr1_GeneCatalog_genes_20131018.gff.....
# problem with:  Parbr1_GeneCatalog_genes_20131018.gff
# 306, Working on Parsp1_GeneCatalog_genes_20141011.gff.....
# problem with:  Parsp1_GeneCatalog_genes_20141011.gff
# 307, Working on Patat1_GeneCatalog_genes_20130514.gff.....
# problem with:  Patat1_GeneCatalog_genes_20130514.gff
# 308, Working on Paxam1_GeneCatalog_genes_20150425.gff.....
# problem with:  Paxam1_GeneCatalog_genes_20150425.gff
# 309, Working on Paxin1_GeneCatalog_genes_20110501.gff.....
# problem with:  Paxin1_GeneCatalog_genes_20110501.gff
# 310, Working on Paxru1_GeneCatalog_genes_20120726.gff.....
# problem with:  Paxru1_GeneCatalog_genes_20120726.gff
# 311, Working on Penac1_GeneCatalog_genes_20140123.gff.....
# problem with:  Penac1_GeneCatalog_genes_20140123.gff
# 312, Working on Penbi1_GeneCatalog_genes_20130602.gff.....
# problem with:  Penbi1_GeneCatalog_genes_20130602.gff
# 313, Working on Penbr2_GeneCatalog_genes_20130810.gff.....
# problem with:  Penbr2_GeneCatalog_genes_20130810.gff
# 314, Working on PenbrAgRF18_1_GeneCatalog_genes_20131217.gff.....
# problem with:  PenbrAgRF18_1_GeneCatalog_genes_20131217.gff
# 315, Working on Penca1_GeneCatalog_genes_20130524.gff.....
# problem with:  Penca1_GeneCatalog_genes_20130524.gff
# 316, Working on Pench1_GeneCatalog_genes_20120123.gff.....
# problem with:  Pench1_GeneCatalog_genes_20120123.gff
# 317, Working on PenchWisc1_1_GeneCatalog_genes_20140114.gff.....
# problem with:  PenchWisc1_1_GeneCatalog_genes_20140114.gff
# 318, Working on Pendi1_GeneCatalog_genes_20131020.gff.....
# problem with:  Pendi1_GeneCatalog_genes_20131020.gff
# 319, Working on Penex1_GeneCatalog_genes_20130524.gff.....
# problem with:  Penex1_GeneCatalog_genes_20130524.gff
# 320, Working on Penfe1_GeneCatalog_genes_20130528.gff.....
# problem with:  Penfe1_GeneCatalog_genes_20130528.gff
# 321, Working on Pengl1_GeneCatalog_genes_20130524.gff.....
# problem with:  Pengl1_GeneCatalog_genes_20130524.gff
# 322, Working on Penja1_GeneCatalog_genes_20140203.gff.....
# problem with:  Penja1_GeneCatalog_genes_20140203.gff
# 323, Working on Penla1_GeneCatalog_genes_20130529.gff.....
# problem with:  Penla1_GeneCatalog_genes_20130529.gff
# 324, Working on Penox1_GeneCatalog_genes_20131211.gff.....
# problem with:  Penox1_GeneCatalog_genes_20131211.gff
# 325, Working on Penra1_GeneCatalog_genes_20140107.gff.....
# problem with:  Penra1_GeneCatalog_genes_20140107.gff
# 326, Working on Perma1_GeneCatalog_genes_20141217.gff.....
# problem with:  Perma1_GeneCatalog_genes_20141217.gff
# 327, Working on Phaal1_GeneCatalog_genes_20130924.gff.....
# problem with:  Phaal1_GeneCatalog_genes_20130924.gff
# 328, Working on Phaca1_GeneCatalog_genes_20101213.gff.....
# problem with:  Phaca1_GeneCatalog_genes_20101213.gff
# 329, Working on Phchr2_GeneCatalog_genes_20131210.gff.....
# problem with:  Phchr2_GeneCatalog_genes_20131210.gff
# 330, Working on Phisc1_GeneCatalog_genes_20150213.gff.....
# problem with:  Phisc1_GeneCatalog_genes_20150213.gff
# 331, Working on Phlbr1_GeneCatalog_genes_20110325.gff.....
# problem with:  Phlbr1_GeneCatalog_genes_20110325.gff
# 332, Working on Phlgi1_GeneCatalog_genes_20110614.gff.....
# problem with:  Phlgi1_GeneCatalog_genes_20110614.gff
# 333, Working on Photr1_GeneCatalog_genes_20140424.gff.....
# problem with:  Photr1_GeneCatalog_genes_20140424.gff
# 335, Working on Phycit1_GeneCatalog_genes_20140925.gff.....
# problem with:  Phycit1_GeneCatalog_genes_20140925.gff
# 336, Working on Picme2_GeneCatalog_genes_20111110.gff.....
# problem with:  Picme2_GeneCatalog_genes_20111110.gff
# 337, Working on Picpa1_GeneCatalog_genes_20130227.gff.....
# problem with:  Picpa1_GeneCatalog_genes_20130227.gff
# 338, Working on Pstipitisv2.FrozenGeneCatalog20080115.gff.....
# problem with:  Pstipitisv2.FrozenGeneCatalog20080115.gff
# 339, Working on Pieho1_1_GeneCatalog_genes_20130807.gff.....
# problem with:  Pieho1_1_GeneCatalog_genes_20130807.gff
# 340, Working on Pilcr1_GeneCatalog_genes_20120328.gff.....
# problem with:  Pilcr1_GeneCatalog_genes_20120328.gff
# 341, Working on PirE2_1_GeneCatalog_genes_20110421.gff.....
# problem with:  PirE2_1_GeneCatalog_genes_20110421.gff
# 342, Working on Pirin1_GeneCatalog_genes_20111203.gff.....
# problem with:  Pirin1_GeneCatalog_genes_20111203.gff
# 343, Working on Pismi1_GeneCatalog_genes_20120412.gff.....
# problem with:  Pismi1_GeneCatalog_genes_20120412.gff
# 344, Working on Pisti1_GeneCatalog_genes_20120410.gff.....
# problem with:  Pisti1_GeneCatalog_genes_20120410.gff
# 345, Working on Plecu1_GeneCatalog_genes_20150512.gff.....
# problem with:  Plecu1_GeneCatalog_genes_20150512.gff
# 348, Working on Plesi1_GeneCatalog_genes_20130603.gff.....
# problem with:  Plesi1_GeneCatalog_genes_20130603.gff
# 349, Working on Plicr1_GeneCatalog_genes_20111115.gff.....
# problem with:  Plicr1_GeneCatalog_genes_20111115.gff
# 350, Working on Pneji1_GeneCatalog_genes_20130607.gff.....
# problem with:  Pneji1_GeneCatalog_genes_20130607.gff
# 351, Working on Podan2_GeneCatalog_genes_20140114.gff.....
# problem with:  Podan2_GeneCatalog_genes_20140114.gff
# 352, Working on Polar1_GeneCatalog_genes_20130201.gff.....
# problem with:  Polar1_GeneCatalog_genes_20130201.gff
# 353, Working on Polbr1_GeneCatalog_genes_20150501.gff.....
# problem with:  Polbr1_GeneCatalog_genes_20150501.gff
# 354, Working on Polci1_GeneCatalog_genes_20130311.gff.....
# problem with:  Polci1_GeneCatalog_genes_20130311.gff
# 355, Working on Polfu1_GeneCatalog_genes_20140813.gff.....
# problem with:  Polfu1_GeneCatalog_genes_20140813.gff
# 356, Working on Pospl1.filtered_proteins.FrozenGeneCatalog_20090305.gff3.....
# problem with:  Pospl1.filtered_proteins.FrozenGeneCatalog_20090305.gff3
# 357, Working on PosplRSB12_1_GeneCatalog_genes_20111103.gff.....
# problem with:  PosplRSB12_1_GeneCatalog_genes_20111103.gff
# 358, Working on Psean1_1_GeneCatalog_genes_20140109.gff.....
# problem with:  Psean1_1_GeneCatalog_genes_20140109.gff
# 359, Working on Psehu1_GeneCatalog_genes_20130926.gff.....
# problem with:  Psehu1_GeneCatalog_genes_20130926.gff
# 360, Working on Psehy1_GeneCatalog_genes_20140829.gff.....
# problem with:  Psehy1_GeneCatalog_genes_20140829.gff
# 362, Working on Pucst1_GeneCatalog_genes_20130920.gff.....
# problem with:  Pucst1_GeneCatalog_genes_20130920.gff
# 363, Working on Punst1_GeneCatalog_genes_20101026.gff.....
# problem with:  Punst1_GeneCatalog_genes_20101026.gff
# 364, Working on Pycci1_GeneCatalog_genes_20140109.gff.....
# problem with:  Pycci1_GeneCatalog_genes_20140109.gff
# 365, Working on Pycco1_GeneCatalog_genes_20140114.gff.....
# problem with:  Pycco1_GeneCatalog_genes_20140114.gff
# 366, Working on Pycco1662_1_GeneCatalog_genes_20140607.gff.....
# problem with:  Pycco1662_1_GeneCatalog_genes_20140607.gff
# 367, Working on Pycsa1_GeneCatalog_genes_20140123.gff.....
# problem with:  Pycsa1_GeneCatalog_genes_20140123.gff
# 368, Working on Pyrco1_GeneCatalog_genes_20131110.gff.....
# problem with:  Pyrco1_GeneCatalog_genes_20131110.gff
# 369, Working on Pyrsp1_GeneCatalog_genes_20141006.gff.....
# problem with:  Pyrsp1_GeneCatalog_genes_20141006.gff
# 371, Working on Pyrtt1_GeneCatalog_genes_20110408.gff.....
# problem with:  Pyrtt1_GeneCatalog_genes_20110408.gff
# 372, Working on Ramac1_GeneCatalog_genes_20140310.gff.....
# problem with:  Ramac1_GeneCatalog_genes_20140310.gff
# 373, Working on Rambr1_GeneCatalog_genes_20140929.gff.....
# problem with:  Rambr1_GeneCatalog_genes_20140929.gff
# 374, Working on Rhich1_GeneCatalog_genes_20131210.gff.....
# problem with:  Rhich1_GeneCatalog_genes_20131210.gff
# 375, Working on Rhier1_GeneCatalog_genes_20141012.gff.....
# problem with:  Rhier1_GeneCatalog_genes_20141012.gff
# 376, Working on Rhili1_GeneCatalog_genes_20150422.gff.....
# problem with:  Rhili1_GeneCatalog_genes_20150422.gff
# 377, Working on Rhimi1_1_GeneCatalog_genes_20130624.gff.....
# problem with:  Rhimi1_1_GeneCatalog_genes_20130624.gff
# 378, Working on Rhimi_ATCC11559_1_GeneCatalog_genes_20150408.gff.....
# problem with:  Rhimi_ATCC11559_1_GeneCatalog_genes_20150408.gff
# 379, Working on Rhimi_ATCC52814_1_GeneCatalog_genes_20150309.gff.....
# problem with:  Rhimi_ATCC52814_1_GeneCatalog_genes_20150309.gff
# 381, Working on Rhisa1_GeneCatalog_genes_20141012.gff.....
# problem with:  Rhisa1_GeneCatalog_genes_20141012.gff
# 382, Working on Rhiso1_GeneCatalog_genes_20131028.gff.....
# problem with:  Rhiso1_GeneCatalog_genes_20131028.gff
# 383, Working on Rhivi1_GeneCatalog_genes_20140605.gff.....
# problem with:  Rhivi1_GeneCatalog_genes_20140605.gff
# 384, Working on Rhoba1_1_GeneCatalog_genes_20100913.gff.....
# problem with:  Rhoba1_1_GeneCatalog_genes_20100913.gff
# 385, Working on Rhodsp1_GeneCatalog_genes_20150111.gff.....
# problem with:  Rhodsp1_GeneCatalog_genes_20150111.gff
# 386, Working on Rhomi1_GeneCatalog_genes_20140320.gff.....
# problem with:  Rhomi1_GeneCatalog_genes_20140320.gff
# 387, Working on Rhosp1_GeneCatalog_genes_20140409.gff.....
# problem with:  Rhosp1_GeneCatalog_genes_20140409.gff
# 388, Working on Rhoto1_GeneCatalog_genes_20141208.gff.....
# problem with:  Rhoto1_GeneCatalog_genes_20141208.gff
# 389, Working on Rhyru1_1_GeneCatalog_genes_20150204.gff.....
# problem with:  Rhyru1_1_GeneCatalog_genes_20150204.gff
# 390, Working on Ricme1_GeneCatalog_genes_20130412.gff.....
# problem with:  Ricme1_GeneCatalog_genes_20130412.gff
# 391, Working on Rozal1_1_GeneCatalog_genes_20140111.gff.....
# problem with:  Rozal1_1_GeneCatalog_genes_20140111.gff
# 392, Working on Rutfi1_GeneCatalog_genes_20150501.gff.....
# problem with:  Rutfi1_GeneCatalog_genes_20150501.gff
# 393, Working on Sacce1_GeneCatalog_genes_20101210.gff.....
# problem with:  Sacce1_GeneCatalog_genes_20101210.gff
# 394, Working on SacceM3707_1_GeneCatalog_genes_20120712.gff.....
# problem with:  SacceM3707_1_GeneCatalog_genes_20120712.gff
# 395, Working on SacceM3836_1_GeneCatalog_genes_20120712.gff.....
# problem with:  SacceM3836_1_GeneCatalog_genes_20120712.gff
# 396, Working on SacceM3837_1_GeneCatalog_genes_20120713.gff.....
# problem with:  SacceM3837_1_GeneCatalog_genes_20120713.gff
# 397, Working on SacceM3838_1_GeneCatalog_genes_20120714.gff.....
# problem with:  SacceM3838_1_GeneCatalog_genes_20120714.gff
# 398, Working on SacceM3839_1_GeneCatalog_genes_20120714.gff.....
# problem with:  SacceM3839_1_GeneCatalog_genes_20120714.gff
# 399, Working on SacceYB210_1_GeneCatalog_genes_20130329.gff.....
# problem with:  SacceYB210_1_GeneCatalog_genes_20130329.gff
# 400, Working on Sacpr1_GeneCatalog_genes_20140222.gff.....
# problem with:  Sacpr1_GeneCatalog_genes_20140222.gff
# 401, Working on Saico1_GeneCatalog_genes_20110913.gff.....
# problem with:  Saico1_GeneCatalog_genes_20110913.gff
# 402, Working on Sarco1_GeneCatalog_genes_20150213.gff.....
# problem with:  Sarco1_GeneCatalog_genes_20150213.gff
# 403, Working on Schco3_GeneCatalog_genes_20130812.gff.....
# problem with:  Schco3_GeneCatalog_genes_20130812.gff
# 404, Working on Schco_LoeD_1_GeneCatalog_genes_20130531.gff.....
# problem with:  Schco_LoeD_1_GeneCatalog_genes_20130531.gff
# 405, Working on Schco_TatD_1_GeneCatalog_genes_20130515.gff.....
# problem with:  Schco_TatD_1_GeneCatalog_genes_20130515.gff
# 406, Working on Schcy1_GeneCatalog_genes_20131210.gff.....
# problem with:  Schcy1_GeneCatalog_genes_20131210.gff
# 407, Working on Schja1_GeneCatalog_genes_20131031.gff.....
# problem with:  Schja1_GeneCatalog_genes_20131031.gff
# 408, Working on Schoc1_GeneCatalog_genes_20131210.gff.....
# problem with:  Schoc1_GeneCatalog_genes_20131210.gff
# 409, Working on Schpa1_GeneCatalog_genes_20131225.gff.....
# problem with:  Schpa1_GeneCatalog_genes_20131225.gff
# 410, Working on Schpo1_GeneCatalog_genes_20130111.gff.....
# problem with:  Schpo1_GeneCatalog_genes_20130111.gff
# 411, Working on Sclci1_GeneCatalog_genes_20120626.gff.....
# problem with:  Sclci1_GeneCatalog_genes_20120626.gff
# 412, Working on Sclsc1_GeneCatalog_genes_20110903.gff.....
# problem with:  Sclsc1_GeneCatalog_genes_20110903.gff
# 413, Working on Sebve1_GeneCatalog_genes_20120626.gff.....
# problem with:  Sebve1_GeneCatalog_genes_20120626.gff
# 414, Working on Sepmu1_GeneCatalog_genes_20100915.gff.....
# problem with:  Sepmu1_GeneCatalog_genes_20100915.gff
# 415, Working on Seppo1_GeneCatalog_genes_20110720.gff.....
# problem with:  Seppo1_GeneCatalog_genes_20110720.gff
# 416, Working on Sepsp1_GeneCatalog_genes_20150424.gff.....
# problem with:  Sepsp1_GeneCatalog_genes_20150424.gff
# 418, Working on SerlaS7_9_2_GeneCatalog_genes_20120319.gff.....
# problem with:  SerlaS7_9_2_GeneCatalog_genes_20120319.gff
# 419, Working on Serla_varsha1_GeneCatalog_genes_20110916.gff.....
# problem with:  Serla_varsha1_GeneCatalog_genes_20110916.gff
# 420, Working on Setho1_GeneCatalog_genes_20150424.gff.....
# problem with:  Setho1_GeneCatalog_genes_20150424.gff
# 421, Working on Settu1_GeneCatalog_genes_20110305.gff.....
# problem with:  Settu1_GeneCatalog_genes_20110305.gff
# 422, Working on Sisbr1_GeneCatalog_genes_20130805.gff.....
# problem with:  Sisbr1_GeneCatalog_genes_20130805.gff
# 423, Working on Sisni1_GeneCatalog_genes_20130806.gff.....
# problem with:  Sisni1_GeneCatalog_genes_20130806.gff
# 424, Working on Sissu1_GeneCatalog_genes_20130130.gff.....
# problem with:  Sissu1_GeneCatalog_genes_20130130.gff
# 425, Working on Sodal1_GeneCatalog_genes_20130716.gff.....
# problem with:  Sodal1_GeneCatalog_genes_20130716.gff
# 427, Working on Sphst1_GeneCatalog_genes_20120430.gff.....
# problem with:  Sphst1_GeneCatalog_genes_20120430.gff
# 428, Working on Spofi1_GeneCatalog_genes_20130818.gff.....
# problem with:  Spofi1_GeneCatalog_genes_20130818.gff
# 429, Working on Spoli1_GeneCatalog_genes_20140310.gff.....
# problem with:  Spoli1_GeneCatalog_genes_20140310.gff
# 430, Working on Spore1_GeneCatalog_genes_20131031.gff.....
# problem with:  Spore1_GeneCatalog_genes_20131031.gff
# 431, Working on Sporo1.filtered_proteins.FilteredModels1.gff3.....
# problem with:  Sporo1.filtered_proteins.FilteredModels1.gff3
# 432, Working on Spoth2_GeneCatalog_genes_20101221.gff.....
# problem with:  Spoth2_GeneCatalog_genes_20101221.gff
# 433, Working on Stagr1_GeneCatalog_genes_20141015.gff.....
# problem with:  Stagr1_GeneCatalog_genes_20141015.gff
# 434, Working on Stano2_GeneCatalog_genes_20110506.gff.....
# problem with:  Stano2_GeneCatalog_genes_20110506.gff
# 435, Working on Stasp1_GeneCatalog_genes_20141004.gff.....
# problem with:  Stasp1_GeneCatalog_genes_20141004.gff
# 436, Working on Stehi1_GeneCatalog_genes_20101026.gff.....
# problem with:  Stehi1_GeneCatalog_genes_20101026.gff
# 437, Working on Suibr1_GeneCatalog_genes_20130323.gff.....
# problem with:  Suibr1_GeneCatalog_genes_20130323.gff
# 438, Working on Suigr1_GeneCatalog_genes_20150504.gff3.....
# problem with:  Suigr1_GeneCatalog_genes_20150504.gff3
# 439, Working on Suihi1_GeneCatalog_genes_20150416.gff3.....
# problem with:  Suihi1_GeneCatalog_genes_20150416.gff3
# 440, Working on Suilu1_GeneCatalog_genes_20121001.gff.....
# problem with:  Suilu1_GeneCatalog_genes_20121001.gff
# 441, Working on Symat1_GeneCatalog_genes_20150304.gff.....
# problem with:  Symat1_GeneCatalog_genes_20150304.gff
# 442, Working on Symko1_GeneCatalog_genes_20121126.gff.....
# problem with:  Symko1_GeneCatalog_genes_20121126.gff
# 443, Working on Talma1_2_GeneCatalog_genes_20140114.gff.....
# problem with:  Talma1_2_GeneCatalog_genes_20140114.gff
# 444, Working on Talst1_2_GeneCatalog_genes_20140114.gff.....
# problem with:  Talst1_2_GeneCatalog_genes_20140114.gff
# 445, Working on Tapde1_1_GeneCatalog_genes_20130601.gff.....
# problem with:  Tapde1_1_GeneCatalog_genes_20130601.gff
# 446, Working on Terbo2_GeneCatalog_genes_20141124.gff.....
# problem with:  Terbo2_GeneCatalog_genes_20141124.gff
# 447, Working on Ternu1_GeneCatalog_genes_20140925.gff.....
# problem with:  Ternu1_GeneCatalog_genes_20140925.gff
# 448, Working on Tescy1_GeneCatalog_genes_20150113.gff.....
# problem with:  Tescy1_GeneCatalog_genes_20150113.gff
# 449, Working on Theau1_GeneCatalog_genes_20120830.gff.....
# problem with:  Theau1_GeneCatalog_genes_20120830.gff
# 450, Working on Thega1_GeneCatalog_genes_20150318.gff.....
# problem with:  Thega1_GeneCatalog_genes_20150318.gff
# 451, Working on Themi1_GeneCatalog_genes_20141205.gff.....
# problem with:  Themi1_GeneCatalog_genes_20141205.gff
# 452, Working on Thian1_GeneCatalog_genes_20140328.gff.....
# problem with:  Thian1_GeneCatalog_genes_20140328.gff
# 453, Working on Thiap1_GeneCatalog_genes_20140116.gff.....
# problem with:  Thiap1_GeneCatalog_genes_20140116.gff
# 454, Working on Thiar1_GeneCatalog_genes_20131210.gff.....
# problem with:  Thiar1_GeneCatalog_genes_20131210.gff
# 455, Working on Thihy1_GeneCatalog_genes_20140109.gff.....
# problem with:  Thihy1_GeneCatalog_genes_20140109.gff
# 456, Working on Thite2_GeneCatalog_genes_20101221.gff.....
# problem with:  Thite2_GeneCatalog_genes_20101221.gff
# 457, Working on ThoPMI491_1_GeneCatalog_genes_20140726.gff.....
# problem with:  ThoPMI491_1_GeneCatalog_genes_20140726.gff
# 458, Working on Tilan2_GeneCatalog_genes_20140224.gff.....
# problem with:  Tilan2_GeneCatalog_genes_20140224.gff
# 459, Working on Tilwa1_GeneCatalog_genes_20141225.gff.....
# problem with:  Tilwa1_GeneCatalog_genes_20141225.gff
# 460, Working on Torde1_GeneCatalog_genes_20150128.gff.....
# problem with:  Torde1_GeneCatalog_genes_20150128.gff
# 461, Working on Torra1_GeneCatalog_genes_20150428.gff.....
# problem with:  Torra1_GeneCatalog_genes_20150428.gff
# 462, Working on Totfu1_GeneCatalog_genes_20140831.gff.....
# problem with:  Totfu1_GeneCatalog_genes_20140831.gff
# 463, Working on Trace1_GeneCatalog_genes_20150503.gff.....
# problem with:  Trace1_GeneCatalog_genes_20150503.gff
# 464, Working on Traci1_GeneCatalog_genes_20150209.gff.....
# problem with:  Traci1_GeneCatalog_genes_20150209.gff
# 465, Working on Tralj1_GeneCatalog_genes_20140625.gff.....
# problem with:  Tralj1_GeneCatalog_genes_20140625.gff
# 466, Working on Trave1_GeneCatalog_genes_20101111.gff.....
# problem with:  Trave1_GeneCatalog_genes_20101111.gff
# 468, Working on Trepe1_GeneCatalog_genes_20140415.gff.....
# problem with:  Trepe1_GeneCatalog_genes_20140415.gff
# 469, Working on Triab1_1_GeneCatalog_genes_20130513.gff.....
# problem with:  Triab1_1_GeneCatalog_genes_20130513.gff
# 470, Working on Trias1_GeneCatalog_genes_20120305.gff.....
# problem with:  Trias1_GeneCatalog_genes_20120305.gff
# 471, Working on Tatroviridev2_FrozenGeneCatalog_20100319.gff3.....
# problem with:  Tatroviridev2_FrozenGeneCatalog_20100319.gff3
# 472, Working on Tribi1_GeneCatalog_genes_20141117.gff.....
# problem with:  Tribi1_GeneCatalog_genes_20141117.gff
# 473, Working on Trich1_GeneCatalog_genes_20150114.gff.....
# problem with:  Trich1_GeneCatalog_genes_20150114.gff
# 474, Working on Trici4_GeneCatalog_genes_20131015.gff.....
# problem with:  Trici4_GeneCatalog_genes_20131015.gff
# 475, Working on Trigu1_GeneCatalog_genes_20141217.gff.....
# problem with:  Trigu1_GeneCatalog_genes_20141217.gff
# 476, Working on Triha1_GeneCatalog_genes_20120306.gff.....
# problem with:  Triha1_GeneCatalog_genes_20120306.gff
# 477, Working on Trilo3_GeneCatalog_genes_20130918.gff.....
# problem with:  Trilo3_GeneCatalog_genes_20130918.gff
# 478, Working on Trima3_GeneCatalog_genes_20130329.gff.....
# problem with:  Trima3_GeneCatalog_genes_20130329.gff
# 479, Working on Triol1_GeneCatalog_genes_20140430.gff.....
# problem with:  Triol1_GeneCatalog_genes_20140430.gff
# 480, Working on Tripe1_GeneCatalog_genes_20150117.gff.....
# problem with:  Tripe1_GeneCatalog_genes_20150117.gff
# 481, Working on TreeseiV2_FrozenGeneCatalog20081022.gff.....
# problem with:  TreeseiV2_FrozenGeneCatalog20081022.gff
# 482, Working on TrireRUTC30_1_GeneCatalog_genes_20110526.gff.....
# problem with:  TrireRUTC30_1_GeneCatalog_genes_20110526.gff
# 483, Working on Triru1_GeneCatalog_genes_20130826.gff.....
# problem with:  Triru1_GeneCatalog_genes_20130826.gff
# 484, Working on Trisp1_GeneCatalog_genes_20140301.gff.....
# problem with:  Trisp1_GeneCatalog_genes_20140301.gff
# 485, Working on Triver1_GeneCatalog_genes_20131203.gff.....
# problem with:  Triver1_GeneCatalog_genes_20131203.gff
# 486, Working on Tvirens_v2.FrozenGeneCatalog_20100318.gff.....
# problem with:  Tvirens_v2.FrozenGeneCatalog_20100318.gff
# 487, Working on Tryvi1_GeneCatalog_genes_20130617.gff.....
# problem with:  Tryvi1_GeneCatalog_genes_20130617.gff
# 488, Working on Tubme1_GeneCatalog_genes_20111120.gff.....
# problem with:  Tubme1_GeneCatalog_genes_20111120.gff
# 489, Working on Tulca1_GeneCatalog_genes_20120608.gff.....
# problem with:  Tulca1_GeneCatalog_genes_20120608.gff
# 490, Working on Umbra1_GeneCatalog_genes_20121109.gff.....
# problem with:  Umbra1_GeneCatalog_genes_20121109.gff
# 491, Working on Uncre1_GeneCatalog_genes_20131024.gff.....
# problem with:  Uncre1_GeneCatalog_genes_20131024.gff
# 492, Working on Ustma1.filtered_proteins.BroadModels1.gff3.....
# problem with:  Ustma1.filtered_proteins.BroadModels1.gff3
# 493, Working on Ustsp1_GeneCatalog_genes_20150106.gff.....
# problem with:  Ustsp1_GeneCatalog_genes_20150106.gff
# 494, Working on Valla1_GeneCatalog_genes_20141003.gff.....
# problem with:  Valla1_GeneCatalog_genes_20141003.gff
# 495, Working on Venin1_GeneCatalog_genes_20141010.gff.....
# problem with:  Venin1_GeneCatalog_genes_20141010.gff
# 496, Working on Venpi1_GeneCatalog_genes_20150407.gff.....
# problem with:  Venpi1_GeneCatalog_genes_20150407.gff
# 497, Working on Veral1_GeneCatalog_genes_20131030.gff.....
# problem with:  Veral1_GeneCatalog_genes_20131030.gff
# 498, Working on Verda1_GeneCatalog_genes_20110524.gff.....
# problem with:  Verda1_GeneCatalog_genes_20110524.gff
# 499, Working on Veren1_GeneCatalog_genes_20140626.gff.....
# problem with:  Veren1_GeneCatalog_genes_20140626.gff
# 500, Working on Volvo1_GeneCatalog_genes_20130703.gff.....
# problem with:  Volvo1_GeneCatalog_genes_20130703.gff
# 501, Working on Walic1_GeneCatalog_genes_20131017.gff.....
# problem with:  Walic1_GeneCatalog_genes_20131017.gff
# 502, Working on Walse1_GeneCatalog_genes_20100910.gff.....
# problem with:  Walse1_GeneCatalog_genes_20100910.gff
# 503, Working on Wesor1_GeneCatalog_genes_20140626.gff.....
# problem with:  Wesor1_GeneCatalog_genes_20140626.gff
# 504, Working on Wican1_GeneCatalog_genes_20110222.gff.....
# problem with:  Wican1_GeneCatalog_genes_20110222.gff
# 505, Working on Wilmi1_GeneCatalog_genes_20130716.gff.....
# problem with:  Wilmi1_GeneCatalog_genes_20130716.gff
# 506, Working on Wolco1_GeneCatalog_genes_20100915.gff.....
# problem with:  Wolco1_GeneCatalog_genes_20100915.gff
# 507, Working on Xanpa2_GeneCatalog_genes_20140928.gff.....
# problem with:  Xanpa2_GeneCatalog_genes_20140928.gff
# 508, Working on Xerba1_GeneCatalog_genes_20150320.gff.....
# problem with:  Xerba1_GeneCatalog_genes_20150320.gff
# 509, Working on Xylhe1_GeneCatalog_genes_20130827.gff.....
# problem with:  Xylhe1_GeneCatalog_genes_20130827.gff
# 510, Working on Yarli1_GeneCatalog_genes_20130122.gff.....
# problem with:  Yarli1_GeneCatalog_genes_20130122.gff
# 511, Working on Zasce1_GeneCatalog_genes_20120808.gff.....
# problem with:  Zasce1_GeneCatalog_genes_20120808.gff
# 512, Working on Zoprh1_GeneCatalog_genes_20130606.gff.....
# problem with:  Zoprh1_GeneCatalog_genes_20130606.gff
# 513, Working on Zygro1_GeneCatalog_genes_20150128.gff.....
# problem with:  Zygro1_GeneCatalog_genes_20150128.gff
# 514, Working on Zymar1_GeneCatalog_genes_20141012.gff.....
# problem with:  Zymar1_GeneCatalog_genes_20141012.gff
# 515, Working on Zymps1_GeneCatalog_genes_20141012.gff.....
# problem with:  Zymps1_GeneCatalog_genes_20141012.gff
