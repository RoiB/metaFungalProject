# %%
### ignore wrong start and stop with different choice of choosing the boudary
### use the leftmost or rightmost as boudary and not neccessarily start or stop

# %%
import sys; sys.path.append("/home/richard/research/tools/")
import GenerateTestSetModuleV1

import subprocess

# %% [markdown]
# ## Officially start to build test set

# %%
GtfSource = '/storage3/w/richard/meta2015/finalTestSet20151002/gtf_converted_from_gff/'
mixAnnotationFiles = os.listdir(GtfSource)
good_annotation = filter(lambda x: 'good' in x, mixAnnotationFiles)
shortNames = map(lambda x: x.split('_GeneCatalog')[0], good_annotation)
multiGtfTarget = '/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/'
multiGtfNames = []

# %%
fastaSource = '/storage3/w/richard/meta2015/placeForRNASeq/'
fastafiles = [filter(lambda x: '.fasta' in x and '.gz' not in x, os.listdir(fastaSource+shortName+'/data')) for shortName in shortNames]
fastafiles = [item[0] for item in fastafiles]

# %%
targetFastaLocation = '/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/'
targetGtfLocation = '/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/'

# %% [markdown]
# 1) pick multi-gene

# %%
for filename in good_annotation:
    command = ('python /home/richard/research/tools/pickMultiGene.py {}{} {}{}.multiExon.gtf'
               .format(GtfSource, filename, multiGtfTarget, filename[:-4]))
    multiGtfNames.append(filename[:-4]+'.multiExon.gtf')
#     print command
#     subprocess.check_call(command, shell=True)

# %% [markdown]
# 2) update annotation and cut fasta: shortName, good_annotation and fastafiles have the same order

# %%
for i in range(len(shortNames)):
    print shortNames[i],multiGtfNames[i],fastafiles[i]
    assert shortNames[i] in multiGtfNames[i]
    print shortNames[i], fastafiles[i]
    assert shortNames[i] in fastafiles[i]
    
    shortName = shortNames[i].lower()
    intergenic_length = 200
    
    sourceFasta = '{}{}/data/{}'.format(fastaSource,shortNames[i],fastafiles[i])
    print "\t",sourceFasta
    sourceGtf = multiGtfTarget + multiGtfNames[i]
    print "\t",sourceGtf
    targetFasta = targetFastaLocation + fastafiles[i][:-5]+'cut'+'.fasta'
    print "\t",targetFasta
    targetGtf = targetGtfLocation + multiGtfNames[i][:-3]+'updated.gtf'
    print "\t",targetGtf
    GenerateTestSetModuleV1.makeTestSet(shortName, intergenic_length, sourceGtf, sourceFasta, targetGtf, targetFasta)
    print 
    print
# Out:
# Ophdi1 Ophdi1_GeneCatalog_genes_20140614.f.good.multiExon.gtf Ophdi1_AssemblyScaffolds.fasta
# Ophdi1 Ophdi1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Ophdi1/data/Ophdi1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Ophdi1_GeneCatalog_genes_20140614.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Ophdi1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Ophdi1_GeneCatalog_genes_20140614.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Ophdi1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Ophdi1_GeneCatalog_genes_20140614.f.good.multiExon.updated.gtf
#
#
# Spofi1 Spofi1_GeneCatalog_genes_20130818.f.good.multiExon.gtf Spofi1_AssemblyScaffolds.fasta
# Spofi1 Spofi1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Spofi1/data/Spofi1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Spofi1_GeneCatalog_genes_20130818.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Spofi1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Spofi1_GeneCatalog_genes_20130818.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Spofi1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Spofi1_GeneCatalog_genes_20130818.f.good.multiExon.updated.gtf
#
#
# Gloin1 Gloin1_GeneCatalog_genes_20120510.f.good.multiExon.gtf Gloin1_AssemblyScaffolds.fasta
# Gloin1 Gloin1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Gloin1/data/Gloin1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Gloin1_GeneCatalog_genes_20120510.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Gloin1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Gloin1_GeneCatalog_genes_20120510.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Gloin1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Gloin1_GeneCatalog_genes_20120510.f.good.multiExon.updated.gtf
#
#
# Trias1 Trias1_GeneCatalog_genes_20120305.f.good.multiExon.gtf Trias1_AssemblyScaffolds.fasta
# Trias1 Trias1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Trias1/data/Trias1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Trias1_GeneCatalog_genes_20120305.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Trias1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Trias1_GeneCatalog_genes_20120305.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Trias1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Trias1_GeneCatalog_genes_20120305.f.good.multiExon.updated.gtf
#
#
# Cenge3 Cenge3_GeneCatalog_genes_20130403.f.good.multiExon.gtf Cenge3_AssemblyScaffolds.fasta
# Cenge3 Cenge3_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Cenge3/data/Cenge3_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Cenge3_GeneCatalog_genes_20130403.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Cenge3_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Cenge3_GeneCatalog_genes_20130403.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Cenge3_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Cenge3_GeneCatalog_genes_20130403.f.good.multiExon.updated.gtf
#
#
# Sphst1 Sphst1_GeneCatalog_genes_20120430.f.good.multiExon.gtf Sphst1_AssemblyScaffolds.fasta
# Sphst1 Sphst1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Sphst1/data/Sphst1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Sphst1_GeneCatalog_genes_20120430.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Sphst1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Sphst1_GeneCatalog_genes_20120430.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Sphst1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Sphst1_GeneCatalog_genes_20120430.f.good.multiExon.updated.gtf
#
#
# Phchr2 Phchr2_GeneCatalog_genes_20131210.f.good.multiExon.gtf Phchr2_AssemblyScaffolds.fasta
# Phchr2 Phchr2_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Phchr2/data/Phchr2_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Phchr2_GeneCatalog_genes_20131210.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Phchr2_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Phchr2_GeneCatalog_genes_20131210.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Phchr2_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Phchr2_GeneCatalog_genes_20131210.f.good.multiExon.updated.gtf
#
#
# HypEC38_1 HypEC38_1_GeneCatalog_genes_20120308.f.good.multiExon.gtf HypEC38_1_AssemblyScaffolds.fasta
# HypEC38_1 HypEC38_1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/HypEC38_1/data/HypEC38_1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/HypEC38_1_GeneCatalog_genes_20120308.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/HypEC38_1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/HypEC38_1_GeneCatalog_genes_20120308.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/HypEC38_1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/HypEC38_1_GeneCatalog_genes_20120308.f.good.multiExon.updated.gtf
#
#
# Conco1 Conco1_GeneCatalog_genes_20120213.f.good.multiExon.gtf Conco1_AssemblyScaffolds.fasta
# Conco1 Conco1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Conco1/data/Conco1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Conco1_GeneCatalog_genes_20120213.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Conco1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Conco1_GeneCatalog_genes_20120213.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Conco1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Conco1_GeneCatalog_genes_20120213.f.good.multiExon.updated.gtf
#
#
# Croqu1 Croqu1_GeneCatalog_genes_20120612.f.good.multiExon.gtf Croqu1_AssemblyScaffolds.fasta
# Croqu1 Croqu1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Croqu1/data/Croqu1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Croqu1_GeneCatalog_genes_20120612.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Croqu1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Croqu1_GeneCatalog_genes_20120612.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Croqu1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Croqu1_GeneCatalog_genes_20120612.f.good.multiExon.updated.gtf
#
#
# Obbri1 Obbri1_GeneCatalog_genes_20140615.f.good.multiExon.gtf Obbri1_AssemblyScaffolds.fasta
# Obbri1 Obbri1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Obbri1/data/Obbri1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Obbri1_GeneCatalog_genes_20140615.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Obbri1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Obbri1_GeneCatalog_genes_20140615.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Obbri1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Obbri1_GeneCatalog_genes_20140615.f.good.multiExon.updated.gtf
#
#
# Aspoch1 Aspoch1_GeneCatalog_genes_20140127.f.good.multiExon.gtf Aspoch1_AssemblyScaffolds.fasta
# Aspoch1 Aspoch1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Aspoch1/data/Aspoch1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Aspoch1_GeneCatalog_genes_20140127.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Aspoch1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Aspoch1_GeneCatalog_genes_20140127.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Aspoch1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Aspoch1_GeneCatalog_genes_20140127.f.good.multiExon.updated.gtf
#
#
# Aurvu1 Aurvu1_GeneCatalog_genes_20140723.f.good.multiExon.gtf Aurvu1_AssemblyScaffolds.fasta
# Aurvu1 Aurvu1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Aurvu1/data/Aurvu1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Aurvu1_GeneCatalog_genes_20140723.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Aurvu1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Aurvu1_GeneCatalog_genes_20140723.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Aurvu1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Aurvu1_GeneCatalog_genes_20140723.f.good.multiExon.updated.gtf
#
#
# Pneji1 Pneji1_GeneCatalog_genes_20130607.f.good.multiExon.gtf Pneji1_AssemblyScaffolds.fasta
# Pneji1 Pneji1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Pneji1/data/Pneji1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Pneji1_GeneCatalog_genes_20130607.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Pneji1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Pneji1_GeneCatalog_genes_20130607.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Pneji1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Pneji1_GeneCatalog_genes_20130607.f.good.multiExon.updated.gtf
#
#
# Disac1 Disac1_GeneCatalog_genes_20130805.f.good.multiExon.gtf Disac1_AssemblyScaffolds.fasta
# Disac1 Disac1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Disac1/data/Disac1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Disac1_GeneCatalog_genes_20130805.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Disac1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Disac1_GeneCatalog_genes_20130805.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Disac1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Disac1_GeneCatalog_genes_20130805.f.good.multiExon.updated.gtf
#
#
# Neopa1 Neopa1_GeneCatalog_genes_20130909.f.good.multiExon.gtf Neopa1_AssemblyScaffolds.fasta
# Neopa1 Neopa1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Neopa1/data/Neopa1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Neopa1_GeneCatalog_genes_20130909.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Neopa1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Neopa1_GeneCatalog_genes_20130909.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Neopa1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Neopa1_GeneCatalog_genes_20130909.f.good.multiExon.updated.gtf
#
#
# Veren1 Veren1_GeneCatalog_genes_20140626.f.good.multiExon.gtf Veren1_AssemblyScaffolds.fasta
# Veren1 Veren1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Veren1/data/Veren1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Veren1_GeneCatalog_genes_20140626.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Veren1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Veren1_GeneCatalog_genes_20140626.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Veren1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Veren1_GeneCatalog_genes_20140626.f.good.multiExon.updated.gtf
#
#
# SerlaS7_9_2 SerlaS7_9_2_GeneCatalog_genes_20120319.f.good.multiExon.gtf SerlaS7_9_2_AssemblyScaffolds.fasta
# SerlaS7_9_2 SerlaS7_9_2_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/SerlaS7_9_2/data/SerlaS7_9_2_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/SerlaS7_9_2_GeneCatalog_genes_20120319.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/SerlaS7_9_2_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/SerlaS7_9_2_GeneCatalog_genes_20120319.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/SerlaS7_9_2_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/SerlaS7_9_2_GeneCatalog_genes_20120319.f.good.multiExon.updated.gtf
#
#
# Hebcy2 Hebcy2_GeneCatalog_genes_20120913.f.good.multiExon.gtf Hebcy2_AssemblyScaffolds.fasta
# Hebcy2 Hebcy2_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Hebcy2/data/Hebcy2_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Hebcy2_GeneCatalog_genes_20120913.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Hebcy2_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Hebcy2_GeneCatalog_genes_20120913.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Hebcy2_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Hebcy2_GeneCatalog_genes_20120913.f.good.multiExon.updated.gtf
#
#
# Conli1 Conli1_GeneCatalog_genes_20130808.f.good.multiExon.gtf Conli1_AssemblyScaffolds.fasta
# Conli1 Conli1_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Conli1/data/Conli1_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Conli1_GeneCatalog_genes_20130808.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Conli1_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Conli1_GeneCatalog_genes_20130808.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Conli1_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Conli1_GeneCatalog_genes_20130808.f.good.multiExon.updated.gtf
#
#
# Tilan2 Tilan2_GeneCatalog_genes_20140224.f.good.multiExon.gtf Tilan2_AssemblyScaffolds.fasta
# Tilan2 Tilan2_AssemblyScaffolds.fasta
# 	/storage3/w/richard/meta2015/placeForRNASeq/Tilan2/data/Tilan2_AssemblyScaffolds.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/goodMultiExonGtf/Tilan2_GeneCatalog_genes_20140224.f.good.multiExon.gtf
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Tilan2_AssemblyScaffolds.cut.fasta
# 	/home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Tilan2_GeneCatalog_genes_20140224.f.good.multiExon.updated.gtf
# multi-fasta file is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetCutFasta/Tilan2_AssemblyScaffolds.cut.fasta
# updated annotation is saved at: /home/richard/research/tests/Nov9UpdatedTestSetAndTest/TestSetMultiExonGtf/Tilan2_GeneCatalog_genes_20140224.f.good.multiExon.updated.gtf
