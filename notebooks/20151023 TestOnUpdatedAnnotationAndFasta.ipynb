# %%
import pandas as pd

# %%
full_info = pd.read_csv('/home/richard/research/data_small/fullTableInfoGff3GffRNAESwithDensity20150829.csv')
full_info.index = full_info.shortName

shortNames= filter(lambda x: len(x) < 15, os.listdir('/storage3/w/richard/meta2015/placeForRNASeq/'))
shortNames = map(lambda x: x.rstrip(), shortNames)

# %%
full_info.ix[shortNames,['gc','intronDensityGff']]
# Out:
#                gc  intronDensityGff
# shortName
# Aspoch1      44.2              2.23
# Disac1       52.7              1.17
# Cenge3       37.5              1.93
# Conli1       51.9              1.98
# Trias1       47.3              1.68
# Pneji1       28.4              4.74
# Ophdi1       51.7              1.59
# HypEC38_1    40.1              1.86
# Hebcy2       48.4              4.24
# Clafu1       48.8              1.18
# Aurvu1       56.8              4.22
# SerlaS7_9_2  45.3              4.73
# Veren1       41.2              1.84
# Gloin1       27.7              2.46
# Obbri1       53.6              5.02
# Tilan2       56.0              2.32
# Phchr2       56.8              4.41
# Sphst1       44.4              3.67
# Conco1       27.7              1.78
# Neopa1       56.8              2.16
# Croqu1       41.1              3.35
# Spofi1       26.4              1.70
