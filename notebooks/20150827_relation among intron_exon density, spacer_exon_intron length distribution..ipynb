# %%
'''
1. Fresh run on all genomes with the lastest GeneMark-ES
2. Parse GeneMark-ES output model file in the last run and plot exon/spacer/intron length distribution 
3. find connect between exon density and the exon/spacer/intron distribution
Build class ESModel, to extract information(spacer, exon, intron length distribution)
'''
import pandas as pd
import re
import numpy as np
import matplotlib.pylab as plt
% matplotlib inline
fulldata = pd.read_csv("../1_DataSmall/fullTableInfoGff3GffRNA.csv")
fulldata.index = fulldata['shortName']
# print fulldata.columns

# The files under the fastapath were obtained from the script created in 2_Consolidation
# buildingMarkovModel part
fastaPath ="/home/richard/largeDataSet/genomeFasta/" 
targetConvergePath = "/home/richard/largeDataSet/ES_Run_Result_Aug27/"
targetPath = "/scratch/fungi/ES_Run_Aug2015/"

# %%
## make scripts to run GeneMark-ES that distribute the work to m machines


##########################################################################
# first of all, copy fasta files to nodes local drive: scratch
# command to check is nodes are good: for((i=10;i<34;i++)); do ssh node0"$i" echo "$i";done
# nodes 007, 031 fails
nodeNum = ["00"+str(i) for i in range(1,34) if i!=7 and i!=31]; nodeNum = map(lambda x: "node"+x[-3:], nodeNum)
print "Number of nodes active:",len(nodeNum)
numNode = len(nodeNum)

# split shortName column as a list of 31 sublist
shortName = list(fulldata['shortName'])
shortNameSublists = [shortName[i::numNode] for i in range(numNode)]

# assign each node a sublist of shortName
nodeJob = zip(nodeNum,shortNameSublists)

# make folder ES_Run_Aug2015 on each node's local drive, /scratch/fungi/ and copy the relavent shortName folder
# mkdir to nodes was performed on command line
script = ""
for node,shorNames in nodeJob:
    for shortName in shorNames:
        script += "ssh {} cp -r {}{} {}\n".format(node,fastaPath,shortName, targetPath)
with open("/home/richard/tempFile/cp_fasta.sh",'w') as f: f.write(script)
##########################################################################

##########################################################################
#execute GeneMark-ES on from each node

es_command = "/home/alexl/DISTR/gmes_petap/gmes_petap.pl --ES --fungus --min_contig 10000 --cores 8 --v  --seq "
script = ""
for node,shorNames in nodeJob:
    for shortName in shorNames:
        try:
            script += 'nohup ssh {} "cd {}{}; {}{}; cd .." &\n '.format(node,targetPath,shortName,es_command,fulldata.loc[shortName]['fastaName'][:-3])
        except:
            print "problem with",shortName
with open("/home/richard/tempFile/run_ES_Aug2015.sh",'w') as f: f.write(script)  

# print script
##########################################################################
## The above script has problem
## the correct way to do it is to add nohup the first time it use a new node

## copy mod file on the 4th run
modfilePath = "run/ES_C_4/ES_C_4.mod"
targetModPath = "/home/richard/largeDataSet/ES_Run_modfileAug2015/"
script = ""
for node,shorNames in nodeJob:
    for shortName in shorNames:
        script += 'ssh {} cp {}{}/{} {}{}.ES_C_4.mod\n'.format(node, targetPath, shortName,modfilePath,targetModPath, shortName)
with open("/home/richard/tempFile/cp_run_ES_mod_Aug2015.sh",'w') as f: f.write(script)
# Out:
# Number of nodes active: 31
# problem with Neute_matA2
# problem with Pospl1
# problem with Crypa2
# problem with Ustma1
# problem with Sporo1

# %%
print script
# Out:
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Aaoar1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aaoar1.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Ashgo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ashgo1.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Aurde3_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aurde3_1.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/CerAGI/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/CerAGI.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Colzo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Colzo1.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Diocr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Diocr1.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Gloac1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Gloac1.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Jamsp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Jamsp1.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Malsy1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Malsy1_1.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Myrin1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Myrin1.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Paxru1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Paxru1.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/PirE2_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/PirE2_1.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Ramac1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ramac1.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Schco3/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Schco3.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Stano2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Stano2.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Tralj1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Tralj1.ES_C_4.mod
# ssh node001 cp /scratch/fungi/ES_Run_Aug2015/Venpi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Venpi1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Acain1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Acain1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Ashgo1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ashgo1_1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Aurpu_var_mel1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aurpu_var_mel1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Cersp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cersp1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/ConPMI546/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/ConPMI546.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Disac1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Disac1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Gloci1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Gloci1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Karrh1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Karrh1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Marbr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Marbr1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Mytre1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Mytre1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Penac1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Penac1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Pirin1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pirin1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Rambr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rambr1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Schco_LoeD_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Schco_LoeD_1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Stasp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Stasp1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Trave1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Trave1.ES_C_4.mod
# ssh node002 cp /scratch/fungi/ES_Run_Aug2015/Veral1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Veral1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Acema1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Acema1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Aspac1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspac1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Aurpu_var_nam1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aurpu_var_nam1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Cersu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cersu1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Conco1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Conco1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Dotse1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Dotse1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Gloin1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Gloin1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Kazaf1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Kazaf1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Marfi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Marfi1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Nadfu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Nadfu1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Penbi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Penbi1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Pismi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pismi1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Rhich1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhich1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Schco_TatD_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Schco_TatD_1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Stehi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Stehi1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Treme1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Treme1.ES_C_4.mod
# ssh node003 cp /scratch/fungi/ES_Run_Aug2015/Verda1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Verda1.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Aciri1_iso/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aciri1_iso.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Aspbr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspbr1.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Aurpu_var_pul1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aurpu_var_pul1.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Cerun2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cerun2.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Conli1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Conli1.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Dotsy1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Dotsy1.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Glost2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Glost2.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Klula1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Klula1.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Marpt1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Marpt1.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Naifl1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Naifl1.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Penbr2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Penbr2.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Pisti1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pisti1.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Rhier1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhier1.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Schcy1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Schcy1.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Suibr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Suibr1.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Trepe1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Trepe1.ES_C_4.mod
# ssh node004 cp /scratch/fungi/ES_Run_Aug2015/Veren1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Veren1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Aciri1_meta/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aciri1_meta.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Aspca3/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspca3.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Aurpu_var_sub1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aurpu_var_sub1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Cerzm1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cerzm1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Conlig1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Conlig1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Elmca1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Elmca1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Glotr1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Glotr1_1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Lacam1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Lacam1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Maseb1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Maseb1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Necha2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Necha2.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/PenbrAgRF18_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/PenbrAgRF18_1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Plecu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Plecu1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Rhili1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhili1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Schja1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Schja1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Suigr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Suigr1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Triab1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Triab1_1.ES_C_4.mod
# ssh node005 cp /scratch/fungi/ES_Run_Aug2015/Volvo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Volvo1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Acral2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Acral2.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Aspcam1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspcam1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Aurvu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aurvu1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Chagl_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Chagl_1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Conpu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Conpu1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Enccu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Enccu1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Grocl1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Grocl1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Lacbi2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Lacbi2.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Meimi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Meimi1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Nempa1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Nempa1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Penca1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Penca1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/PleosPC15_2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/PleosPC15_2.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Rhimi1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhimi1_1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Schoc1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Schoc1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Suihi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Suihi1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Trias1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Trias1.ES_C_4.mod
# ssh node006 cp /scratch/fungi/ES_Run_Aug2015/Walic1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Walic1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Acrst1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Acrst1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Aspcl1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspcl1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Babin1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Babin1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Chalo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Chalo1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Conth1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Conth1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Enche1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Enche1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Guyne1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Guyne1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Laesu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Laesu1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Melbi2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Melbi2.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Neofi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Neofi1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Pench1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pench1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/PleosPC9_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/PleosPC9_1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Rhimi_ATCC11559_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhimi_ATCC11559_1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Schpa1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Schpa1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Suilu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Suilu1.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Triat2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Triat2.ES_C_4.mod
# ssh node008 cp /scratch/fungi/ES_Run_Aug2015/Walse1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Walse1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Agabi_varbisH97_2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Agabi_varbisH97_2.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Aspfl1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspfl1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Bacci1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Bacci1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Chiap1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Chiap1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Copci1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Copci1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Encin1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Encin1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Gyman1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Gyman1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Leisp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Leisp1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Melli1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Melli1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Neole1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Neole1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/PenchWisc1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/PenchWisc1_1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Plesi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Plesi1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Rhimi_ATCC52814_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhimi_ATCC52814_1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Schpo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Schpo1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Symat1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Symat1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Tribi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Tribi1.ES_C_4.mod
# ssh node009 cp /scratch/fungi/ES_Run_Aug2015/Wesor1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Wesor1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Agabi_varbur_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Agabi_varbur_1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Aspfo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspfo1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Basun1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Basun1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Chove1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Chove1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Copci_AmutBmut1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Copci_AmutBmut1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Encro1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Encro1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Gymau1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Gymau1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Lenfl1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Lenfl1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Mellp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Mellp1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Neopa1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Neopa1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Pendi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pendi1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Plicr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Plicr1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Rhior3/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhior3.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Sclci1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Sclci1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Symko1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Symko1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Trich1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Trich1.ES_C_4.mod
# ssh node010 cp /scratch/fungi/ES_Run_Aug2015/Wican1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Wican1.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Agahy1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Agahy1.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Aspfu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspfu1.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Batde5/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Batde5.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/ClaPMI390/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/ClaPMI390.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Corca1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Corca1.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Entbi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Entbi1.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Gymch1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Gymch1.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Lenti6_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Lenti6_1.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Melpu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Melpu1.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Neucr2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Neucr2.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Penex1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Penex1.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Pneji1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pneji1.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Rhisa1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhisa1.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Sclsc1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Sclsc1.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Talma1_2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Talma1_2.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Trici4/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Trici4.ES_C_4.mod
# ssh node011 cp /scratch/fungi/ES_Run_Aug2015/Wilmi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Wilmi1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Altal1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Altal1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Aspfu_A1163_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspfu_A1163_1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Bauco1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Bauco1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Clael1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Clael1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Corgl3/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Corgl3.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Erebi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Erebi1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Gymci1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Gymci1_1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Lenti7_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Lenti7_1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Melsp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Melsp1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Neucr_trp3_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Neucr_trp3_1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Penfe1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Penfe1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Podan2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Podan2.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Rhiso1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhiso1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Sebve1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Sebve1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Talst1_2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Talst1_2.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Trigu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Trigu1.ES_C_4.mod
# ssh node012 cp /scratch/fungi/ES_Run_Aug2015/Wolco1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Wolco1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Altbr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Altbr1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Aspgl1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspgl1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Beaba1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Beaba1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Clafu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Clafu1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Corma2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Corma2.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Eryha1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Eryha1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Gymlu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Gymlu1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Lepmu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Lepmu1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Melti1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Melti1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Neudi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Neudi1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Pengl1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pengl1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Polar1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Polar1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Rhivi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhivi1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Sepmu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Sepmu1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Tapde1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Tapde1_1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Triha1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Triha1.ES_C_4.mod
# ssh node013 cp /scratch/fungi/ES_Run_Aug2015/Xanpa2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Xanpa2.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Amamu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Amamu1.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Aspka1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspka1_1.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Bimnz1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Bimnz1.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Clagr3/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Clagr3.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Cormi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cormi1.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Eurhe1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Eurhe1.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Gyrli1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Gyrli1.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Leppa1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Leppa1.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Melva1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Melva1.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Neute_matA2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Neute_matA2.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Penja1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Penja1.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Polbr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Polbr1.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Rhoba1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhoba1_1.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Seppo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Seppo1.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Terbo2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Terbo2.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Trilo3/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Trilo3.ES_C_4.mod
# ssh node014 cp /scratch/fungi/ES_Run_Aug2015/Xerba1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Xerba1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Amath1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Amath1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Aspni7/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspni7.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Bjead1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Bjead1_1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Clapy1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Clapy1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Croqu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Croqu1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Eutla1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Eutla1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Hanpo2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Hanpo2.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Leugo1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Leugo1_1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Metac1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Metac1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Neute_mat_a1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Neute_mat_a1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Penla1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Penla1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Polci1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Polci1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Rhodsp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhodsp1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Sepsp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Sepsp1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Ternu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ternu1.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Trima3/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Trima3.ES_C_4.mod
# ssh node015 cp /scratch/fungi/ES_Run_Aug2015/Xylhe1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Xylhe1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Amnli1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Amnli1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Aspni_DSM_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspni_DSM_1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Blugr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Blugr1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Cloro1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cloro1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Cryne_H99_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cryne_H99_1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Exigl1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Exigl1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Hanva1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Hanva1_1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Leumo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Leumo1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Metan1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Metan1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Nieex1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Nieex1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Penox1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Penox1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Polfu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Polfu1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Rhomi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhomi1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/SerlaS7_3_2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/SerlaS7_3_2.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Tescy1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Tescy1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Triol1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Triol1.ES_C_4.mod
# ssh node016 cp /scratch/fungi/ES_Run_Aug2015/Yarli1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Yarli1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Amore1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Amore1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Aspni_NRRL3_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspni_NRRL3_1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Boled1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Boled1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Cocca1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cocca1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Cryne_JEC21_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cryne_JEC21_1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Exova1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Exova1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Hebcy2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Hebcy2.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Lichy1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Lichy1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Metbi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Metbi1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Nosce1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Nosce1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Penra1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Penra1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Pospl1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pospl1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Rhosp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhosp1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/SerlaS7_9_2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/SerlaS7_9_2.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Theau1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Theau1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Tripe1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Tripe1.ES_C_4.mod
# ssh node017 cp /scratch/fungi/ES_Run_Aug2015/Zasce1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Zasce1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Antav1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Antav1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Aspni_bvT_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspni_bvT_1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Botbo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Botbo1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/CocheC4_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/CocheC4_1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Crypa2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Crypa2.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Fibra1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Fibra1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Hesve2finisherSC/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Hesve2finisherSC.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Linin1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Linin1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Micca1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Micca1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Obbri1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Obbri1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Perma1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Perma1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/PosplRSB12_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/PosplRSB12_1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Rhoto1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhoto1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Serla_varsha1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Serla_varsha1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Thega1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Thega1.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Trire2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Trire2.ES_C_4.mod
# ssh node018 cp /scratch/fungi/ES_Run_Aug2015/Zoprh1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Zoprh1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Antlo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Antlo1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Aspnid1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspnid1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Botci1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Botci1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/CocheC5_3/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/CocheC5_3.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Cryvi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cryvi1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Fibsp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Fibsp1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Hetan2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Hetan2.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Linth1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Linth1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Mictr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Mictr1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Oidma1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Oidma1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Phaal1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Phaal1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Psean1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Psean1_1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Rhyru1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rhyru1_1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Setho1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Setho1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Themi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Themi1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/TrireRUTC30_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/TrireRUTC30_1.ES_C_4.mod
# ssh node019 cp /scratch/fungi/ES_Run_Aug2015/Zygro1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Zygro1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Antsi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Antsi1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Aspnov1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspnov1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Botdo1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Botdo1_1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Cocim1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cocim1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Cucbe1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cucbe1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Fishe1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Fishe1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Hetpy1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Hetpy1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Lipst1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Lipst1_1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Mixos1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Mixos1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Ompol1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ompol1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Phaca1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Phaca1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Psehu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Psehu1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Ricme1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ricme1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Settu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Settu1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Thian1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Thian1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Triru1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Triru1.ES_C_4.mod
# ssh node020 cp /scratch/fungi/ES_Run_Aug2015/Zymar1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Zymar1.ES_C_4.mod
# ssh node021 cp /scratch/fungi/ES_Run_Aug2015/Apimo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Apimo1.ES_C_4.mod
# ssh node021 cp /scratch/fungi/ES_Run_Aug2015/Aspoch1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspoch1.ES_C_4.mod
# ssh node021 cp /scratch/fungi/ES_Run_Aug2015/Bysci1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Bysci1.ES_C_4.mod
# ssh node021 cp /scratch/fungi/ES_Run_Aug2015/Coclu2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Coclu2.ES_C_4.mod
# ssh node021 cp /scratch/fungi/ES_Run_Aug2015/Cybja1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cybja1.ES_C_4.mod
# ssh node021 cp /scratch/fungi/ES_Run_Aug2015/Fomme1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Fomme1.ES_C_4.mod
# ssh node021 cp /scratch/fungi/ES_Run_Aug2015/Hisca1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Hisca1.ES_C_4.mod
# ssh node021 cp /scratch/fungi/ES_Run_Aug2015/Lizem1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Lizem1.ES_C_4.mod
# ssh node021 cp /scratch/fungi/ES_Run_Aug2015/Monha1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Monha1.ES_C_4.mod
# ssh node021 cp /scratch/fungi/ES_Run_Aug2015/Onnsc1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Onnsc1.ES_C_4.mod
# ssh node021 cp /scratch/fungi/ES_Run_Aug2015/Phchr2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Phchr2.ES_C_4.mod
# ssh node021 cp /scratch/fungi/ES_Run_Aug2015/Psehy1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Psehy1.ES_C_4.mod
# ssh node021 cp /scratch/fungi/ES_Run_Aug2015/Rozal1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Rozal1_1.ES_C_4.mod
# ...
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Artel1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Artel1.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Aspte1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspte1.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Canca1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Canca1.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Colca1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Colca1.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Debha1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Debha1.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Fusox2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Fusox2.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/HypCO275_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/HypCO275_1.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Lorju1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Lorju1.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Morel1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Morel1.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Panru1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Panru1.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Phybl2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Phybl2.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Pycco1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pycco1.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/SacceM3837_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/SacceM3837_1.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Sphst1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Sphst1.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Tilan2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Tilan2.ES_C_4.mod
# ssh node026 cp /scratch/fungi/ES_Run_Aug2015/Tulca1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Tulca1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Artol1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Artol1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Asptu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Asptu1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Canta1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Canta1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Coler1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Coler1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Decga1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Decga1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Fusve1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Fusve1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/HypEC38_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/HypEC38_1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Macan1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Macan1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Mucci2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Mucci2.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Panst_KUC8834_1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Panst_KUC8834_1_1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Phycit1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Phycit1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Pycco1662_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pycco1662_1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/SacceM3838_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/SacceM3838_1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Spofi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Spofi1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Tilwa1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Tilwa1.ES_C_4.mod
# ssh node027 cp /scratch/fungi/ES_Run_Aug2015/Umbra1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Umbra1.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Arxad1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Arxad1.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Aspve1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspve1.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Cante1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cante1.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Colfa1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Colfa1.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Dekbr2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Dekbr2.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Fusve2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Fusve2.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Hypbu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Hypbu1.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Macfu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Macfu1.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Mutel1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Mutel1.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Parbr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Parbr1.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Picme2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Picme2.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Pycsa1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pycsa1.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/SacceM3839_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/SacceM3839_1.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Spoli1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Spoli1.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Torde1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Torde1.ES_C_4.mod
# ssh node028 cp /scratch/fungi/ES_Run_Aug2015/Uncre1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Uncre1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Ascim1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ascim1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Aspwe1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspwe1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Catan1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Catan1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Colgr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Colgr1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Delco1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Delco1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Galma1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Galma1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Hypsu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Hypsu1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Macph1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Macph1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Mycfi2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Mycfi2.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Parsp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Parsp1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Picpa1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Picpa1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Pyrco1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pyrco1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/SacceYB210_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/SacceYB210_1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Spore1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Spore1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Torra1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Torra1.ES_C_4.mod
# ssh node029 cp /scratch/fungi/ES_Run_Aug2015/Ustma1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ustma1.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Ascni1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ascni1.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Aspzo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aspzo1.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Cenge3/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cenge3.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Colhi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Colhi1.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Denbi1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Denbi1.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Ganpr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ganpr1.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Hyspu1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Hyspu1_1.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Maggr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Maggr1.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Mycgr3/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Mycgr3.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Patat1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Patat1.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Picst3/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Picst3.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Pyrsp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pyrsp1.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Sacpr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Sacpr1.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Sporo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Sporo1.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Totfu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Totfu1.ES_C_4.mod
# ssh node030 cp /scratch/fungi/ES_Run_Aug2015/Ustsp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ustsp1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Ascru1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ascru1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Atrsp2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Atrsp2.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Cepal1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cepal1_1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Colso1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Colso1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Dicsq1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Dicsq1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Gansp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Gansp1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Ilysp1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ilysp1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Magpo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Magpo1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Myche1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Myche1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Paxam1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Paxam1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Pieho1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pieho1_1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Pyrtr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pyrtr1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Saico1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Saico1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Spoth2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Spoth2.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Trace1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Trace1.ES_C_4.mod
# ssh node032 cp /scratch/fungi/ES_Run_Aug2015/Valla1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Valla1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Ascsa1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Ascsa1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Aulhe2/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Aulhe2.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Cepfr1_1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Cepfr1_1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Colsu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Colsu1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Didex1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Didex1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Glalo1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Glalo1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Jaaar1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Jaaar1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Malgl1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Malgl1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Myrdu1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Myrdu1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Paxin1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Paxin1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Pilcr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pilcr1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Pyrtt1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Pyrtt1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Sarco1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Sarco1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Stagr1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Stagr1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Traci1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Traci1.ES_C_4.mod
# ssh node033 cp /scratch/fungi/ES_Run_Aug2015/Venin1/run/ES_C_4/ES_C_4.mod /home/richard/largeDataSet/ES_Run_modfileAug2015/Venin1.ES_C_4.mod

# %%
## create an extra column of label to point out if ES is successful
## parse from the nohup file to capture ES failure
ES_fail_text = ""
with open("/home/richard/research/1_DataSmall/textToBeParsed/ES_output_20150828.txt") as f: ES_fail_text = f.read()
## capture failure by regular expression
pattern = "ES_Run_Aug2015\/(.*?)\/run/ES_C_4"
shortNamefailedES = set(re.findall(pattern, ES_fail_text))
print "There were {} genomes failed GeneMark-ES run.".format(len(shortNamefailedES))

# add the column to fulldata set
ES = ['pass' for i in range(fulldata.shape[0])]
fulldata['ES'] = ES; 
for shortName in shortNamefailedES: fulldata.loc[shortName,'ES'] = 'fail'
noGenomeSpecies = ['Neute_matA2','Pospl1','Crypa2','Ustma1','Sporo1']
for shortName in noGenomeSpecies: fulldata.loc[shortName,'ES'] = 'NA'
fulldata.to_csv("/home/richard/research/1_DataSmall/fullTableInfoGff3GffRNAES_20150828.csv", index = None)
# Out:
# There were 71 genomes failed GeneMark-ES run.

# %%
############################################
spacerData = []
switch = False
with open("/home/richard/largeDataSet/ES_Run_modfileAug2015/Aaoar1.ES_C_4.mod") as f:
    for line in f:
        if switch:
            spacerData.append(line)
        if "$BP_ACC_DISTR" in line:
            switch = True
        if "40\t" in line:
            switch = False
            break
            
spacerData = map(lambda line: line.rstrip().split("\t"), spacerData)
spacerDistr = map(lambda (a,b): float(b), spacerData)
positionProb = np.array(spacerDistr)
# print positionProb
range(2,41)[positionProb.argmax()]
##############################################
# Out:
# 8

# %%
## Build class ESModel, to extract information(spacer, exon, intron length distribution)
class ESModel():
    """Take in 4th run of model file as text and extract info"""
    def __init__(self, filename):
        self.f = open(filename)
    
    def maxSpacerPosition(self):
        '''
        return the position with the highest probability
        '''
        spacerData = []
        switch = False
        for line in self.f:
            if switch:
                spacerData.append(line)
            if "$BP_ACC_DISTR" in line:
                switch = True
            if "40\t" in line:
                switch = False
                break

        spacerData = map(lambda line: line.rstrip().split("\t"), spacerData)
        spacerDistr = map(lambda (a,b): float(b), spacerData)
        positionProb = np.array(spacerDistr)
        # print positionProb
        return range(2,41)[positionProb.argmax()]
    
    def maxExonPosition(self, length = 9999):
        '''
        return the position with the highest probability
        '''
        exonData = []
        switch = False
        for line in self.f:
            if switch:
                exonData.append(line)
            if "$EXON_DISTR" in line:
                switch = True
            if switch and "{}\t".format(length) in line:
                switch = False
                break

        exonData = map(lambda line: line.rstrip().split("\t"), exonData)
        exonDistr = map(lambda (a,b): float(b), exonData)
        positionProb = np.array(exonDistr)
        # print positionProb
        try:
            return range(3,10000)[positionProb.argmax()]
        except:
            return 'NA'

    def maxIntronPosition(self, length = 3000):
            '''
            return the position with the highest probability
            '''
            intronData = []
            switch = False
            for line in self.f:
                if switch:
                    intronData.append(line)
                if "$INTRON_DISTR" in line:
                    switch = True
                if switch and "{}\t".format(length) in line:
                    switch = False
                    break

            intronData = map(lambda line: line.rstrip().split("\t"), intronData)
            intronDistr = map(lambda (a,b): float(b), intronData)
            positionProb = np.array(intronDistr)
            # print positionProb
            try:
                return range(20,3000)[positionProb.argmax()]
            except:
                return 'NA'

    def maxDonorToBpIntronPosition(self, length = 3000):
            '''
            return the position with the highest probability
            '''
            intronData = []
            switch = False
            for line in self.f:
                if switch:
                    intronData.append(line)
                if "$DON_BP_DISTR" in line:
                    switch = True
                if switch and "{}\t".format(length) in line:
                    switch = False
                    break

            intronData = map(lambda line: line.rstrip().split("\t"), intronData)
            intronDistr = map(lambda (a,b): float(b), intronData)
            positionProb = np.array(intronDistr)
            # print positionProb
            try:
                return range(20,3000)[positionProb.argmax()]
            except:
                return 'NA'
    def close(self):
        self.f.close()

# %%
## add columns for exon density according to gff3, if gff3 is not available, use gff
fulldata = pd.read_csv("../1_DataSmall/fullTableInfoGff3GffRNAES_20150828.csv")
exonDensityGff3 = fulldata['numExonGff3']/fulldata['numGeneGff3']
exonDensityGff = fulldata['numExonGff']/fulldata['numGeneGff']
fulldata['exonDensityGff3'] = exonDensityGff3
fulldata['exonDensityGff'] = exonDensityGff

fulldata.index = fulldata['shortName']
cols = ['shortName', 'longName', 'fastaName', 'gffName', 'gff3Name', 'gc', 'numGeneGff3', 'numExonGff3', 'exonDensityGff3', 'numIntronGff3', 'intronDensityGff3', 'numGeneGff', 'numExonGff', 'exonDensityGff', 'numIntronGff', 'intronDensityGff', 'rnaSeqCount', 'ES']
fulldata = fulldata[cols]
fulldata.to_csv("/home/richard/research/1_DataSmall/fullTableInfoGff3GffRNAESwithDensity20150829.csv", index = None)

# %%
## generate plot of spacer length distribution and figure out the relation between exon density
## find the exon density VS max position
exonDensityExonDistrPair = []
modelFilePath = "/home/richard/largeDataSet/ES_Run_modfileAug2015/"
for shortName in fulldata.index:
    if fulldata.loc[shortName,'ES'] == 'pass':
        filepath = "{}{}{}".format(modelFilePath, shortName,".ES_C_4.mod")
        model = ESModel(filepath)
        ## make a list of 3-tuple, shortName, gc, maxSpacerPosition
        exonDensity1 = fulldata.loc[shortName,'exonDensityGff3']
        exonDensity2 = fulldata.loc[shortName,'exonDensityGff']
        exonDensity = exonDensity1 if pd.isnull(exonDensity1) else exonDensity2
        exonDensityExonDistrPair.append((shortName,exonDensity,model.maxSpacerPosition())) # need to pair this with gc
        model.close()
#         print filepath
data = np.array(exonDensityExonDistrPair)
plt.plot(data[:,1], data[:,2], "o")
plt.xlabel("Exon Density")
plt.ylabel("Position of Spacer with max probability")
plt.title("Max Probability Spacer position VS Exon Density")

# %%
## generate plot of spacer length distribution and figure out the relation between intron density
## find the intron density VS max position
intronDensityExonDistrPair = []
modelFilePath = "/home/richard/largeDataSet/ES_Run_modfileAug2015/"
for shortName in fulldata.index:
    if fulldata.loc[shortName,'ES'] == 'pass':
        filepath = "{}{}{}".format(modelFilePath, shortName,".ES_C_4.mod")
        model = ESModel(filepath)
        ## make a list of 3-tuple, shortName, gc, maxSpacerPosition
        intronDensity1 = fulldata.loc[shortName,'intronDensityGff3']
        intronDensity2 = fulldata.loc[shortName,'intronDensityGff']
        intronDensity = intronDensity1 if pd.isnull(intronDensity1) else intronDensity2
        intronDensityExonDistrPair.append((shortName,intronDensity,model.maxSpacerPosition())) # need to pair this with gc
        model.close()
#         print filepath
data = np.array(intronDensityExonDistrPair)
plt.plot(data[:,1], data[:,2], "o")
plt.xlabel("intron Density")
plt.ylabel("Position of Spacer with max probability")
plt.title("Max Probability Spacer position VS intron Density")

# %%
## count number of species that have intronDesity > 1 and have max(prob) position > 14
intronDensityVSmaxSpacerPosition = pd.DataFrame(data)
f1 = np.array(intronDensityVSmaxSpacerPosition.icol(1), dtype = "float64") > 1
f2 = np.array(intronDensityVSmaxSpacerPosition.icol(2), dtype = 'int32') > 14
sum(f1&f2) # these are mostly the outliers
# Out:
# 16

# %%
## get rid of the part with intron density < 1

## generate plot of spacer length distribution and figure out the relation between intron density
## find the intron density VS max position
intronDensityExonDistrPair = []
modelFilePath = "/home/richard/largeDataSet/ES_Run_modfileAug2015/"

f1 = fulldata['intronDensityGff3'] > 1
f2 = fulldata['intronDensityGff'] > 1
filteredData = fulldata[f1|f2]


for shortName in filteredData.index:
    if filteredData.loc[shortName,'ES'] == 'pass':
        filepath = "{}{}{}".format(modelFilePath, shortName,".ES_C_4.mod")
        model = ESModel(filepath)
        ## make a list of 3-tuple, shortName, gc, maxSpacerPosition
        intronDensity1 = filteredData.loc[shortName,'intronDensityGff3']
        intronDensity2 = filteredData.loc[shortName,'intronDensityGff']
        intronDensity = intronDensity1 if pd.isnull(intronDensity1) else intronDensity2
        intronDensityExonDistrPair.append((shortName,intronDensity,model.maxSpacerPosition())) # need to pair this with gc
        model.close()
#         print filepath
data = np.array(intronDensityExonDistrPair)
plt.plot(data[:,1], data[:,2], "o")
plt.xlabel("intron Density")
plt.ylabel("Position of Spacer with max probability")
# plt.title("Spacer position at Max(Probability) VS intron Density")
plt.title("Spacer length at Max(Probability) position \n VS \nintron Density")

# %%
## generate plot of exon length distribution and figure out the relation between intron density
## find the intron density VS max position
intronDensityExonDistrPair = []
modelFilePath = "/home/richard/largeDataSet/ES_Run_modfileAug2015/"
f1 = fulldata['intronDensityGff3'] > 1
f2 = fulldata['intronDensityGff'] > 1
filteredData = fulldata[f1|f2]
for shortName in filteredData.index:
    if filteredData.loc[shortName,'ES'] == 'pass':
        filepath = "{}{}{}".format(modelFilePath, shortName,".ES_C_4.mod")
        model = ESModel(filepath)
        ## make a list of 3-tuple, shortName, gc, maxSpacerPosition
        intronDensity1 = filteredData.loc[shortName,'intronDensityGff3']
        intronDensity2 = filteredData.loc[shortName,'intronDensityGff']
        intronDensity = intronDensity1 if pd.isnull(intronDensity1) else intronDensity2
        intronDensityExonDistrPair.append((shortName,filteredData.loc[shortName,'gc'],intronDensity,model.maxExonPosition())) # need to pair this with gc
        model.close()
#         print filepath
data = np.array(intronDensityExonDistrPair)

# %%
# plotting continue from last part, X = intron density
plt.plot(data[:,2], data[:,3], "o")
plt.xlabel("Intron Density")
plt.ylabel("Position of Exon with max probability")
# plt.title("Exon position at Max(Probability) VS Intron Density")
plt.title("Exon length at Max(Probability) position \n VS \nintron Density")

# %%
# plotting continue from last part, X = GC
plt.plot(data[:,1], data[:,3], "o")
plt.xlabel("GC")
plt.ylabel("Position of Exon with max probability")
# plt.title("Exon position at max(Probability) VS Intron Density")
plt.title("Exon length at Max(Probability) position VS GC")

# %%
## generate plot of intron length distribution and figure out the relation between intron density
## find the intron density VS max position
intronDensityIntronDistrPair = []
modelFilePath = "/home/richard/largeDataSet/ES_Run_modfileAug2015/"
f1 = fulldata['intronDensityGff3'] > 1
f2 = fulldata['intronDensityGff'] > 1
filteredData = fulldata[f1|f2]
for shortName in filteredData.index:
    if filteredData.loc[shortName,'ES'] == 'pass':
        filepath = "{}{}{}".format(modelFilePath, shortName,".ES_C_4.mod")
        model = ESModel(filepath)
        ## make a list of 3-tuple, shortName, gc, maxSpacerPosition
        intronDensity1 = filteredData.loc[shortName,'intronDensityGff3']
        intronDensity2 = filteredData.loc[shortName,'intronDensityGff']
        intronDensity = intronDensity1 if pd.isnull(intronDensity1) else intronDensity2
        intronDensityIntronDistrPair.append((shortName,filteredData.loc[shortName,'gc'],intronDensity,model.maxIntronPosition())) # need to pair this with gc
        model.close()
#         print filepath
data = np.array(intronDensityIntronDistrPair)

# %%
# plotting continue from last part, X = intron density
plt.plot(data[:,2], data[:,3], "or")
plt.xlabel("Intron Density")
plt.ylabel("Position of Intron with max probability")
# plt.title("Intron position at Max(Probability) VS Intron Density")
plt.title("Intron length at Max(Probability) position \n VS \nintron Density")

# %%
# plotting continue from last part, X = GC
plt.plot(data[:,1], data[:,3], "or")
plt.xlabel("GC")
plt.ylabel("Position of Intron with max probability")
# plt.title("Intron position at Max(Probability) VS GC")
plt.title("Intron length at Max(Probability) position VS GC")

# %%
## generate plot of donor to BP intron length distribution and figure out the relation between intron density
## find the intron density VS max position
intronDensityIntronDistrPair = []
modelFilePath = "/home/richard/largeDataSet/ES_Run_modfileAug2015/"
f1 = fulldata['intronDensityGff3'] > 1
f2 = fulldata['intronDensityGff'] > 1
filteredData = fulldata[f1|f2]
for shortName in filteredData.index:
    if filteredData.loc[shortName,'ES'] == 'pass':
        filepath = "{}{}{}".format(modelFilePath, shortName,".ES_C_4.mod")
        model = ESModel(filepath)
        ## make a list of 3-tuple, shortName, gc, maxSpacerPosition
        intronDensity1 = filteredData.loc[shortName,'intronDensityGff3']
        intronDensity2 = filteredData.loc[shortName,'intronDensityGff']
        intronDensity = intronDensity1 if pd.isnull(intronDensity1) else intronDensity2
        intronDensityIntronDistrPair.append((shortName,filteredData.loc[shortName,'gc'],intronDensity,model.maxDonorToBpIntronPosition())) # need to pair this with gc
        model.close()
#         print filepath
data = np.array(intronDensityIntronDistrPair)

# %%
# plotting continue from last part, X = intron density
plt.plot(data[:,2], data[:,3], "or")
plt.xlabel("Intron Density")
plt.ylabel("Position of Intron with max probability")
# plt.title("Intron position(Donor Site to BP) at Max(Probability) VS Intron Density")
plt.title("Intron position(Donor Site to BP) at Max(Probability) \n VS \nintron Density")

# %%
# plotting continue from last part, X = GC
plt.plot(data[:,1], data[:,3], "or")
plt.xlabel("GC")
plt.ylabel("Position of Intron with max probability")
plt.title("Intron position(Donor Site to BP) at Max(Probability) \nVS\nGC")
