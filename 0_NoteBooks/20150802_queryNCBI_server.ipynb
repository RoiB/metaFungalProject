# %%
'''
make query to ncbi regarding the 363 genomes to see if they have rna seq data 
the server ip was blocked by NCBI, so I have to cp it back to my desktop
please refer to 20150802_queryNCBI_local
'''
import pandas as pd
import urllib2
import xml.etree.ElementTree as ET
info = pd.read_csv("../1_DataSmall/2_completeFileInfo/completeFileInfoWithStatistics.csv")
info
# Out:
#              shortName                                     longName  \
# 0               Aaoar1            Aaosphaeria arxii CBS 175.79 v1.0
# 1           Aciri1_iso                 Acidomyces richmondensis BFW
# 2          Aciri1_meta                 Acidomyces richmondensis BFW
# 3               Acral2                 Acremonium alcalophilum v2.0
# 4    Agabi_varbisH97_2    Agaricus bisporus var bisporus (H97) v2.0
# 5       Agabi_varbur_1    Agaricus bisporus var. burnettii JB137-S8
# 6               Altbr1                      Alternaria brassicicola
# 7               Amamu1                  Amanita muscaria Koide v1.0
# 8               Amath1               Amanita thiersii Skay4041 v1.0
# 9               Amore1                    Amorphotheca resinae v1.0
# 10              Antav1           Anthostoma avocetta NRRL 3190 v1.0
# 11              Antlo1                 Antonospora locustae HM-2013
# 12              Antsi1                        Antrodia sinuosa v1.0
# ...

# %%
base = 'http://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=SRA&term=biomol+rna[Properties]+AND+'
# rnaSeqCount = []
# for i in range(info.shape[0]):
#     longName = "+".join(info.loc[i]['longName'].split())
    
#     try:
#         response = urllib2.urlopen(base+longName)
        
#     except:

# %%
## test code
# test_query = base+"Arthrobotrys+oligospora+ATCC"
test_query = "http://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi?dbfrom=nuccore&db=gene&id=34577062,24475906"
response = urllib2.urlopen(test_query)
res = response.read()
root = ET.fromstring(res)

# %%
res
# Out:
# '<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd"> \n<html>\n<head>\n<title>NCBI - WWW Error Blocked Diagnostic</title>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta http-equiv="pragma" content="no-cache" />\n<meta http-equiv="cache-control" content="no-cache" />\n<meta name="robots" content="noarchive,none" />\n\n<style type="text/css">\nbody {\nmin-width: 950px;\n_width: 950px;\n}\nh1.error {color: red; font-size: 40pt}\n\n#mainContent {\npadding: 1em 2em;\n}\n\ndl#diags {\npadding: 0.5em 0.5em 1.5em 0.5em;\npadding-left: 2em;\nborder: solid 1px #888;\nborder-left: none;\nborder-right: none;\nmargin-bottom:0;\nbackground-color:#eeeeee;\ncolor:#666;\nfont-size: 80%;\n_font-size: 70%;\nfont-family: Verdana, sans-serif;\n}\n\ndl#diags dt {\nfloat: left;\nfont-weight: bold;\nwidth: auto;\n}\n\ndl#diags dd {\nmargin-left:1em;\nfloat: left;\nmargin-right: 2em;\n}\n\n#footer span {\nfloat: left;\ncolor: #888;\
# ...
